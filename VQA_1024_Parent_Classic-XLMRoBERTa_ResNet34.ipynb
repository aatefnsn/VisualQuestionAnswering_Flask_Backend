# %%
import torch
print(torch.__version__)
# Out:
# 1.13.1+cu116

# %%
#from torchtext.vocab import GloVe

#global_vectors = GloVe(name='840B', dim=300)

# %%
#embeddings = global_vectors.get_vecs_by_tokens("hi", lower_case_backup=True)
#print(embeddings)

# %%
#pip install torch==1.12.1

# %%
import torch
print(torch.__version__)
# Out:
# 1.13.1+cu116

# %%
from google.colab import drive
drive.mount('/content/drive/')
# !unzip /content/drive/MyDrive/VQA/train2014.zip -d /content/drive/MyDrive/VQA/
#!unzip /content/drive/MyDrive/VQA/val2014.zip -d /content/drive/MyDrive/VQA/
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000194043.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000219859.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000278135.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000141015.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000280923.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000200024.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000435713.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000249993.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000424160.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000142761.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000532668.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000564904.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000346384.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000560934.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000122356.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000193042.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000072702.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000064795.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000118089.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000082228.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000002148.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000102210.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000281355.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000312076.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000040008.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000483458.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000205131.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000223534.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000309137.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000353559.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000088136.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000550649.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000541343.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000522992.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000079107.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000475185.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000561339.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000273503.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000566439.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000364457.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000006355.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000254078.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000204867.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000266496.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000065712.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000092731.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000173474.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000136043.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000232919.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000223526.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000091973.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000224407.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000129753.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000300454.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000560388.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000292146.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000362839.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000505418.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000565858.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000313971.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000484899.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000464372.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000259316.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000265449.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000334645.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000474405.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000084391.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000014764.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000566236.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000552461.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000237009.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000131579.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000415497.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000167995.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000431492.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000346978.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000097260.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000395007.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000537772.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000411212.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000258714.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000081944.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000353906.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000279762.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000459201.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000057868.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000358545.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000326712.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000478306.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000430391.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000013703.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000137681.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000267192.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000454406.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000461333.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000575149.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000181828.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000202372.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000121535.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000368738.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000425200.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000350784.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000287213.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000093363.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000539789.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000390742.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000531033.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000548964.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000308221.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000476430.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000237034.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000496730.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000513520.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000273710.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000573456.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000495931.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000097296.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000314750.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000146208.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000524253.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000544053.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000069205.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000116326.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000479867.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000561426.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000112459.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000114035.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000101357.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000074842.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000529542.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000222074.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000266271.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000328654.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000301918.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000403899.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000257517.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000177060.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000449179.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000157801.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000289561.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000539189.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000116783.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000114925.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000056705.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000075466.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000364879.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000101749.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000025421.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000283624.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000049095.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000207471.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000440532.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000056857.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000395500.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000208898.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000338760.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000580971.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000517972.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000028518.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000256576.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000528900.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000002886.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000114686.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000258073.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000445392.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000221540.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000493791.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000038718.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000110094.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000440738.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000290969.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000105063.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000172148.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000101050.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000184493.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000501381.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000536103.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000009999.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000462129.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000374598.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000472861.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000052562.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000182118.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000009226.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000369931.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000127330.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000566591.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000233688.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000029915.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000004159.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000030023.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000343204.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000241785.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000218274.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000145264.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000008829.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000337775.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000380455.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000114068.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000360725.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000264322.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000030357.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000365030.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000489085.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000400828.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000484300.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000234642.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000553777.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000535514.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000255877.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000419618.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000412142.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000515464.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000372634.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000179480.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000169517.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000213554.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000237561.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000496918.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000474356.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000082936.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000129689.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000571805.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000037757.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000161083.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000003276.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000255306.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000578041.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000468518.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000311238.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000277491.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000268855.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000554182.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000061045.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000186317.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000208678.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000116204.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000483424.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000494941.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000145174.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000521907.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000191690.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000006424.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000103018.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000280642.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000002229.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000079530.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000504259.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000261871.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000497327.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000231401.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000148824.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000287503.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000423412.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000052270.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000067082.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000237423.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000375674.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000147865.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000344618.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000353274.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000411851.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000262136.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000498138.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000408040.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000573166.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000118775.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000035351.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000143420.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000416516.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000138536.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000280068.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000112805.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000572250.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000169474.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000563488.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000495902.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000004546.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000419767.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000427154.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000569592.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000539313.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000338120.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000470781.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000335184.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000551757.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000377585.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000230428.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000117284.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000112989.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000342592.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000578793.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000419785.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000196294.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000507542.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000281505.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000542186.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000178572.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000543289.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000397190.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000015525.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000056040.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000265744.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000557251.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000500987.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000313579.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000111606.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000003866.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000029391.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000021678.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000282067.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000158680.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000420403.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000250196.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000436932.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000114175.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000425912.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000266533.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000122763.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000105686.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000505098.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000526514.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000558287.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000238217.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000276871.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000510617.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000281763.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000036281.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000465018.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000473102.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000575310.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000360313.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000404579.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000506270.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000102469.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000307940.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000051871.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000198671.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000018201.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000278528.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000517830.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000048685.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000083754.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000118742.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000435920.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000026720.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000332039.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000388894.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000371114.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000213933.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000565429.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000124834.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000519168.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000177182.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000398200.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000386250.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000579679.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000326948.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000236725.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000118769.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000109008.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000080471.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000120518.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000480001.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000176617.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000229415.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000131902.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000098859.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000472729.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000100638.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000375248.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000015268.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000469941.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000002563.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000099907.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000292444.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000532147.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000320566.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000242291.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000390347.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000001108.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000426839.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000335633.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000544264.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000154928.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000163764.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000551793.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000014385.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000184800.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000062617.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000282359.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000579968.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000117512.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000152273.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000204626.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000361145.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000183412.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000067222.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000354235.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000004173.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000487903.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000551063.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000044286.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000160403.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000079572.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000303436.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000099245.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000311578.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000078750.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000502395.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000268622.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000548726.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000182933.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000483045.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000252381.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000480841.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000479651.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000283715.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000341707.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000566495.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000308059.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000449852.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000290420.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000473134.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000523304.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000039460.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000488297.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000020245.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000487399.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000526204.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000075415.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000513221.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000201035.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000380171.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000322530.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000438368.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000334158.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000194200.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000515020.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000009119.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000131419.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000196377.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000208122.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000172987.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000017858.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000187178.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000268151.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000138760.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000480950.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000415588.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000177860.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000280788.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000327000.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000394713.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000388976.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000473294.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000412141.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000404910.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000206465.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000539072.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000571627.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000245823.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000139526.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000205270.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000150652.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000028072.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000425709.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000206676.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000076101.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000563070.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000445620.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000510366.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000578037.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000161473.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000356086.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000277341.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000486547.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000064141.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000574901.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000547742.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000580405.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000285800.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000099628.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000332556.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000569449.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000270109.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000184751.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000468896.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000162283.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000502407.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000485187.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000467491.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000074213.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000352427.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000414828.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000443522.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000046818.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000055410.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000466202.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000158044.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000447103.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000185004.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000573479.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000348487.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000113293.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000314064.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000285355.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000382559.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000017602.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000250801.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000320333.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000216763.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000484273.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000507840.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000391388.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000119755.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000044781.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000125626.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000092747.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000379871.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000460005.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000390914.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000473587.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000038326.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000479504.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000461326.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000132991.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000573533.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000175608.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000311232.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000365950.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000220898.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000391361.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000063299.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000372868.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000424718.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000204728.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000350885.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000164502.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000275771.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000322445.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000429158.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000130563.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000163030.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000235012.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000189645.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000272171.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000310707.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000576157.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000181759.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000063797.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000260882.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000142510.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000062478.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000361437.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000372022.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000013802.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000146584.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000568597.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000347351.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000354794.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000130222.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000541580.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000145155.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000005554.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000571719.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000204603.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000445214.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000547503.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000187162.jpg
# ...
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000234424.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000021095.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000384844.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000122923.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000166522.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000013482.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000249688.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000010015.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000107011.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000166657.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000367809.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000024380.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000012421.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000240685.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000324349.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000444566.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000255486.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000381667.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000538116.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000328381.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000014844.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000578663.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000107691.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000426143.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000444945.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000337883.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000024289.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000092553.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000041311.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000166998.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000044702.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000355236.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000015843.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000397205.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000038375.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000128215.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000250424.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000328242.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000313481.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000337448.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000398936.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000320911.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000464237.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000172040.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000313556.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000130598.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000346562.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000455601.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000379136.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000567836.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000234536.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000278549.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000426988.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000055534.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000372213.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000402120.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000518355.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000037868.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000012696.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000083875.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000174623.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000039531.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000523468.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000062715.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000548662.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000549626.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000416119.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000384643.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000392167.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000055493.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000560754.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000491277.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000389088.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000407926.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000380115.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000329892.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000206530.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000518075.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000041475.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000138370.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000087871.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000171126.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000499920.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000385075.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000100535.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000212359.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000113598.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000004377.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000546695.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000498409.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000402174.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000400443.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000139945.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000190530.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000324339.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000168453.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000271870.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000556001.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000311476.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000139109.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000184518.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000399687.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000330426.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000379558.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000532583.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000026635.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000380715.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000373148.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000274170.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000187025.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000049363.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000344669.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000476874.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000230129.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000305170.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000419798.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000452005.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000089838.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000055607.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000447130.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000100777.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000287105.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000125063.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000270379.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000116006.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000552472.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000540864.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000556855.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000398540.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000287324.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000493187.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000226555.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000197584.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000411505.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000086927.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000351852.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000248979.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000414047.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000379448.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000104248.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000216413.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000493618.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000241325.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000138782.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000499985.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000356064.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000443650.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000021968.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000304587.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000132778.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000136346.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000345585.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000485465.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000041461.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000166592.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000419406.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000125305.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000322892.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000578154.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000189520.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000524773.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000104559.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000110423.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000383446.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000161436.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000090006.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000061072.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000381256.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000008458.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000375027.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000073339.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000564020.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000175057.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000328246.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000298657.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000219869.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000025162.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000341052.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000093789.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000254701.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000177349.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000283267.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000334463.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000500946.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000000531.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000291366.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000533055.jpg
#  extracting: /content/drive/MyDrive/VQA/train2014/COCO_train2014_000000467840.jpg
# Archive:  /content/drive/MyDrive/VQA/val2014.zip
# replace /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000324670.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !unzip /content/drive/MyDrive/VQA/val2014.zip -d /content/drive/MyDrive/VQA/
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000535608.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000279145.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000243495.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000225791.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000428067.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000059383.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000558498.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000376123.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000191304.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000171062.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000014549.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000121152.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000276596.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000029431.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000036349.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000502055.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000438848.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000364973.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000564166.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000323327.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000338581.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000039656.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000071667.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000376046.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000066394.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000277584.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000383518.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000262466.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000153055.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000155312.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000010440.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000541108.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000202503.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000161308.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000153013.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000089924.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000289842.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000191226.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000157465.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000218224.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000030548.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000347422.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000451501.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000374401.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000274599.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000285235.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000298691.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000319726.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000137822.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000566697.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000280017.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000240436.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000368459.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000107831.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000051976.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000476349.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000252829.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000197716.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000222458.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000277738.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000213649.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000406050.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000301735.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000467752.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000126229.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000397404.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000402405.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000350721.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000187271.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000011699.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000335644.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000262189.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000109313.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000348905.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000269964.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000242679.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000579893.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000198163.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000154230.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000222696.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000261097.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000368242.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000310711.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000282942.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000199203.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000459598.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000083331.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000442019.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000571038.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000019624.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000367582.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000308785.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000248019.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000064121.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000172924.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000236784.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000253940.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000368684.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000429530.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000390689.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000075884.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000243104.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000464006.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000155051.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000075857.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000464317.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000071284.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000228197.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000451463.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000394050.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000249129.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000102741.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000231806.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000052340.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000108541.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000317147.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000300784.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000105480.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000225184.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000348162.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000416787.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000167017.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000157019.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000027756.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000561088.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000209898.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000131453.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000417846.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000215244.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000328397.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000324500.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000116208.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000507893.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000157944.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000398507.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000515540.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000211119.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000233023.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000091402.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000239627.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000235564.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000205300.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000139512.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000459502.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000117719.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000229000.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000170000.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000005860.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000494427.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000030423.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000467951.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000204830.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000432239.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000402992.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000472416.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000414852.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000047367.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000352549.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000552075.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000170232.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000363654.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000047435.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000283717.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000504810.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000517249.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000532580.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000571857.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000257470.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000386553.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000542939.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000252342.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000027433.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000337969.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000168974.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000417193.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000096539.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000442979.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000411674.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000121783.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000156858.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000265208.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000100087.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000528575.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000077396.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000206770.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000549171.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000290078.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000227884.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000024285.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000526394.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000235747.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000022215.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000252911.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000002684.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000075611.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000106193.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000193194.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000184446.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000021903.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000045388.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000063855.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000215062.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000189378.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000237844.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000161569.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000563311.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000154431.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000276146.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000578545.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000161605.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000078426.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000488563.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000375015.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000551669.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000152111.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000242246.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000283005.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000450055.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000081004.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000353180.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000471991.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000007072.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000117201.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000177383.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000369309.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000157046.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000561054.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000175933.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000186977.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000297578.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000316423.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000576015.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000262654.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000022371.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000023272.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000434192.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000046872.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000428375.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000333887.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000365386.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000043613.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000033979.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000451102.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000498392.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000093333.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000566975.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000104327.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000115584.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000531349.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000396692.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000075591.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000236837.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000190291.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000449856.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000173217.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000095707.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000192620.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000328091.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000398377.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000549674.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000053677.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000256903.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000248953.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000269254.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000321008.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000536183.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000007506.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000439710.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000089432.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000063240.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000472795.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000030668.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000315162.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000553780.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000444207.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000358055.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000504125.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000541197.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000320150.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000000761.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000561062.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000581183.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000010684.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000251404.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000107840.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000037470.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000373170.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000465272.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000275219.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000457559.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000111004.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000332845.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000573258.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000555119.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000154711.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000233223.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000184994.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000056129.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000102654.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000255470.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000506471.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000483643.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000013721.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000309678.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000173772.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000070657.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000313398.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000148508.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000281725.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000514376.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000153103.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000197870.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000560566.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000575916.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000040729.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000223857.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000528311.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000459662.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000136285.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000277521.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000451095.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000292905.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000448259.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000550084.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000328372.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000433554.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000144896.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000095078.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000271681.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000148730.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000041899.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000216861.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000137211.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000250311.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000093611.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000408535.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000240751.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000297323.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000537513.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000459428.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000279013.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000394840.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000454326.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000434494.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000087493.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000581332.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000133210.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000430473.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000504635.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000357176.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000464296.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000224862.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000538513.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000409867.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000172649.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000099736.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000204360.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000520478.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000565389.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000058111.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000238258.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000318730.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000209904.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000247438.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000214664.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000561514.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000457249.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000213593.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000409125.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000026670.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000542451.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000052966.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000191738.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000309510.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000531875.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000010217.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000050125.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000568290.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000488374.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000413839.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000287828.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000022158.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000516020.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000377406.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000245793.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000453438.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000450719.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000581253.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000241668.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000485368.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000426309.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000450129.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000454102.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000011742.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000113756.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000274063.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000067959.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000077282.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000143215.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000508822.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000321742.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000346687.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000078093.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000139099.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000342929.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000111117.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000522791.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000363039.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000523780.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000249936.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000404897.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000553869.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000570094.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000121188.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000165919.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000576827.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000045648.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000167356.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000203024.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000057323.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000432293.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000363344.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000052527.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000475678.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000495980.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000187876.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000481159.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000097964.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000208050.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000230150.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000059207.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000389129.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000462324.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000071239.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000148282.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000580418.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000204887.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000292347.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000522175.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000209747.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000500473.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000311883.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000573891.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000281625.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000265596.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000031093.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000482574.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000044723.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000045966.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000012860.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000006688.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000552979.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000078537.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000533408.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000482367.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000275695.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000442993.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000192787.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000299838.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000579240.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000529698.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000164759.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000476175.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000548879.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000094865.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000354121.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000483358.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000353982.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000428336.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000278843.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000419378.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000439007.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000262003.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000196919.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000342933.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000513417.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000428140.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000154701.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000510734.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000005600.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000208740.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000212346.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000063661.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000270593.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000482160.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000565954.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000455483.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000484531.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000166563.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000541132.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000445972.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000116951.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000288076.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000365752.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000063521.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000560361.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000293057.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000460347.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000255950.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000238866.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000376236.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000512657.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000487482.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000052413.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000155478.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000470070.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000065270.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000505663.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000021394.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000060049.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000449432.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000552942.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000208406.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000070332.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000143927.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000527374.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000338941.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000191613.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000434142.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000572347.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000109827.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000355450.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000050054.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000317565.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000476415.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000083059.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000155571.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000128516.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000467696.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000001668.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000128978.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000181888.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000069906.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000275058.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000056400.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000531178.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000211141.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000115006.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000225130.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000126974.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000223426.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000356302.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000177535.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000064842.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000036124.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000207670.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000516372.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000355819.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000141524.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000327917.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000567205.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000413538.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000050926.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000124232.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000209788.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000124210.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000530052.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000208107.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000398554.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000018193.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000318671.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000555050.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000408501.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000521419.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000234660.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000492758.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000330790.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000515577.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000388409.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000377231.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000292931.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000577976.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000442480.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000320026.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000460944.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000455343.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000209147.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000066231.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000405547.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000379441.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000519853.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000130651.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000301282.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000511050.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000075001.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000416818.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000572802.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000558114.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000249884.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000294209.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000388398.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000485580.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000402858.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000204749.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000111259.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000136173.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000462289.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000294134.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000522727.jpg
# ...
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000141517.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000404618.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000218026.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000253988.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000265151.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000269419.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000503490.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000567013.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000072000.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000546934.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000364299.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000170191.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000469242.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000138556.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000295006.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000502275.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000103163.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000573066.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000323442.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000305195.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000018575.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000249825.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000209431.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000076334.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000129855.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000251094.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000030595.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000539423.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000266727.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000469877.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000156246.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000222866.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000366295.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000030353.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000078465.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000099182.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000423396.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000211618.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000150301.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000537692.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000078488.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000257053.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000489799.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000235857.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000497351.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000133515.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000314426.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000283131.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000322511.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000479078.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000238598.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000046405.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000198724.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000279838.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000507739.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000064859.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000393423.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000405205.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000442040.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000221272.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000565273.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000158849.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000448205.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000243344.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000393267.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000401018.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000137619.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000367804.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000206260.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000446850.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000300989.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000449180.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000201727.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000182469.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000243852.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000409030.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000294776.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000136941.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000204098.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000182050.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000215596.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000228214.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000406071.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000397459.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000203509.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000293300.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000142934.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000523297.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000485290.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000484425.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000120535.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000180584.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000313228.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000486580.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000563762.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000099481.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000213599.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000062060.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000283028.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000366711.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000308388.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000364133.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000544237.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000199989.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000290282.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000542042.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000274014.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000318022.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000207437.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000461885.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000562708.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000272015.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000541744.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000183786.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000577853.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000181488.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000330079.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000107963.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000327433.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000485343.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000435444.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000324584.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000536235.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000226848.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000270316.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000165831.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000240301.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000144003.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000308167.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000269918.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000400915.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000270677.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000506803.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000094174.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000005443.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000157084.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000437895.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000078499.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000219269.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000117028.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000073470.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000316499.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000351554.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000164779.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000154139.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000258911.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000041373.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000466005.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000066523.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000332877.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000514294.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000070945.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000199927.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000206751.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000036077.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000201045.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000079490.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000079566.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000086988.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000560266.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000254834.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000190783.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000524575.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000433156.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000532620.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000533171.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000074462.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000386584.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000575625.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000000599.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000316123.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000442206.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000411665.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000112698.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000395462.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000368663.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000399049.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000479939.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000132860.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000281315.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000014526.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000154892.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000535313.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000008483.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000259087.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000030667.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000132288.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000155617.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000049682.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000382438.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000488693.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000324492.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000543836.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000551804.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000045516.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000347233.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000154202.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000038210.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000113113.jpg
#  extracting: /content/drive/MyDrive/VQA/val2014/COCO_val2014_000000441814.jpg

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# !ls -lhtr /content/drive/MyDrive/VQA/train2014 | grep jpg | wc -l #82783
# Out:
# 82783

# %%
# !ls -lhtr /content/drive/MyDrive/VQA/val2014 | grep jpg | wc -l #40504
# Out:
# 40504

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.8/dist-packages (4.26.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.12.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.25.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (3.7)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk) (2022.6.2)

# %%
pip install gensim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.8/dist-packages (3.6.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.8/dist-packages (from gensim) (6.3.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.21.6)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.8/dist-packages (from gensim) (1.7.3)

# %%
pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.8/dist-packages (2.6)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorboardX) (3.19.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorboardX) (23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from tensorboardX) (1.21.6)

# %%
pip install tensorboardX --no-cache-dir
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.8/dist-packages (2.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from tensorboardX) (1.21.6)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorboardX) (3.19.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorboardX) (23.0)

# %%
pip install tensorboard
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.8/dist-packages (2.11.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (3.4.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (1.51.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (2.16.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (1.21.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (2.25.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (1.0.1)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (3.19.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (57.4.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard) (6.0.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.12.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.2.2)

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Feb 15 05:47:20 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0    50W / 400W |   4006MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     17688      C                                    4003MiB |
# +-----------------------------------------------------------------------------+

# %%
# This is a sample Python script.

# Press ⌃R to execute it or replace it with your code.
# Press Double ⇧ to search everywhere for classes, files, tool windows, actions, and settings.

# Interface for accessing the VQA dataset.

# This code is based on the code written by Tsung-Yi Lin for MSCOCO Python API available at the following link:
# (https://github.com/pdollar/coco/blob/master/PythonAPI/pycocotools/coco.py).

# The following functions are defined:
#  VQA        - VQA class that loads VQA annotation file and prepares data structures.
#  getQuesIds - Get question ids that satisfy given filter conditions.
#  getImgIds  - Get image ids that satisfy given filter conditions.
#  loadQA     - Load questions and answers with the specified question ids.
#  showQA     - Display the specified questions and answers.
#  loadRes    - Load result file and create result object.

# Help on each function can be accessed by: "help(COCO.function)"

import json
import datetime
import copy

import torch
import numpy as np
from six.moves import cPickle as pickle
import dill
from torch.utils.data import DataLoader

import operator
import numpy as np
import os
import shutil
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.utils.rnn as rnn
from tensorboardX import SummaryWriter
from datetime import datetime
from torchvision import models
import torch.nn.functional as fn
from collections import defaultdict

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import models, transforms
from PIL import Image
from six.moves import cPickle as pickle
from torchvision.datasets.folder import accimage_loader
import argparse


import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class VQA: ## open the dataset JSON
    def __init__(self, annotation_file=None, question_file=None):
        """
           Constructor of VQA helper class for reading and visualizing questions and answers.
        :param annotation_file (str): location of VQA annotation file
        :return:
        """
        # load dataset
        self.dataset = {}
        self.questions = {}
        self.qa = {}
        self.qqa = {}
        self.imgToQA = {}
        if not annotation_file == None and not question_file == None:
            print('loading VQA annotations and questions into memory...')
            #time_t = datetime.datetime.utcnow()
            time_t = datetime.utcnow()
            dataset = json.load(open(annotation_file, 'r'))
            questions = json.load(open(question_file, 'r'))
            print(datetime.utcnow() - time_t)
            self.dataset = dataset
            self.questions = questions
            self.createIndex()

    def createIndex(self):
        # create index
        print('creating index...')
        imgToQA = {ann['image_id']: [] for ann in self.dataset['annotations']}
        qa = {ann['question_id']: [] for ann in self.dataset['annotations']}
        qqa = {ann['question_id']: [] for ann in self.dataset['annotations']}
        #print('imgToQA is ', imgToQA)
        #print(qa)
        #print(qqa)
        for ann in self.dataset['annotations']:
            imgToQA[ann['image_id']] += [ann] # list of image IDs and annotation of each image ID
            qa[ann['question_id']] = ann # List of question ID <-> annotations
        for ques in self.questions['questions']:
            qqa[ques['question_id']] = ques # list of question ID <-> Question
        print('index created!')
        #print(imgToQA)
        #print(qa[1])

        """
        first_n_values = list(imgToQA.values())[0]
        first= list(imgToQA.keys())[0]
        print('Example of imgToQA')
        print('key', first)
        print('Values:', first_n_values)
        """
        """
        Example of imgToQA
        key 458752
        Values: [
            {
                'question_type': 'what is this', 
                'multiple_choice_answer': 'net', 
                'answers': [
                    {'answer': 'net', 'answer_confidence': 'maybe', 'answer_id': 1}, 
                    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 2}, 
                    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 3}, 
                    {'answer': 'netting', 'answer_confidence': 'yes', 'answer_id': 4}, 
                    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 5}, 
                    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 6}, 
                    {'answer': 'mesh', 'answer_confidence': 'maybe', 'answer_id': 7}, 
                    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 8}, 
                    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 9}, 
                    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 10}
                ],
                'image_id': 458752, 
                'answer_type': 'other',
                'question_id': 458752000
            }, 
            {
                'question_type': 'what', 
                'multiple_choice_answer': 'pitcher', 
                'answers': [
                    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 1}, 
                    {'answer': 'catcher', 'answer_confidence': 'no', 'answer_id': 2}, 
                    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 3}, 
                    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 4}, 
                    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 5}, 
                    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 6}, 
                    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 7}, 
                    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 8}, 
                    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 9}, 
                    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 10}
                ], 
                'image_id': 458752, 
                'answer_type': 'other', 
                'question_id': 458752001
            }, 
            {
            'answer_type': 'other', 
            'multiple_choice_answer': 'orange', 
            'answers': [
                {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 1}, 
                {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 2}, 
                {'answer': 'orange', 'answer_confidence': 'maybe', 'answer_id': 3}, 
                {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 4}, 
                {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 5}, 
                {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 6}, 
                {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 7}, 
                {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 8}, 
                {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 9}, 
                {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 10}
            ], 
            'image_id': 458752, 
            'question_type': 'what color is the', 
            'question_id': 458752002
            }, 
            {
            'question_type': 'is this', 
            'multiple_choice_answer': 'yes', 
            'answers': [
                {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1}, 
                {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2}, 
                {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 3}, 
                {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4}, 
                {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 5}, 
                {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 6}, 
                {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7}, 
                {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8}, 
                {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9}, 
                {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 10}
            ], 
            'image_id': 458752, 
            'answer_type': 'yes/no', 
            'question_id': 458752003
            }
        ]
        """
        """
        first_n_values = list(qa.values())[0]
        first = list(qa.keys())[0]
        print('Example of qa')
        print('key', first)
        print('Values:', first_n_values)
        """
        """
        Example of qa
        key 458752000
        Values: {
            'question_type': 'what is this', 
            'multiple_choice_answer': 'net', 
            'answers': [
                {'answer': 'net', 'answer_confidence': 'maybe', 'answer_id': 1}, 
                {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 2}, 
                {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 3}, 
                {'answer': 'netting', 'answer_confidence': 'yes', 'answer_id': 4}, 
                {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 5}, 
                {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 6}, 
                {'answer': 'mesh', 'answer_confidence': 'maybe', 'answer_id': 7}, 
                {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 8}, 
                {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 9}, 
                {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 10}], 
            'image_id': 458752, 
            'answer_type': 'other', 
            'question_id': 458752000
        }
        """
        """
        first_n_values = list(qqa.values())[0]
        first = list(qqa.keys())[0]
        print('Example of qqa')
        print('key', first)
        print('Values:', first_n_values)
        """
        """
        Example of qqa
        key 458752000
        Values: {'image_id': 458752, 'question': 'What is this photo taken looking through?', 'question_id': 458752000}
        """

        # create class members
        self.qa = qa #each question ID with its answers
        self.qqa = qqa #Each question ID with the question itself and image ID
        self.imgToQA = imgToQA # Each image ID with a list of question IDs, each question ID answers

    def info(self):
        """
        Print information about the VQA annotation file.
        :return:
        """
        for key, value in self.datset['info'].items():
            print('%s: %s' % (key, value))

    def getQuesIds(self, imgIds=[], quesTypes=[], ansTypes=[]):
        """
        Get question ids that satisfy given filter conditions. default skips that filter
        :param 	imgIds    (int array)   : get question ids for given imgs
                quesTypes (str array)   : get question ids for given question types
                ansTypes  (str array)   : get question ids for given answer types
        :return:    ids   (int array)   : integer array of question ids
        """
        imgIds = imgIds if type(imgIds) == list else [imgIds]
        quesTypes = quesTypes if type(quesTypes) == list else [quesTypes]
        ansTypes = ansTypes if type(ansTypes) == list else [ansTypes]

        if len(imgIds) == len(quesTypes) == len(ansTypes) == 0:
            anns = self.dataset['annotations']
        else:
            if not len(imgIds) == 0:
                anns = sum([self.imgToQA[imgId] for imgId in imgIds if imgId in self.imgToQA], [])
            else:
                anns = self.dataset['annotations']
            anns = anns if len(quesTypes) == 0 else [ann for ann in anns if ann['question_type'] in quesTypes]
            anns = anns if len(ansTypes) == 0 else [ann for ann in anns if ann['answer_type'] in ansTypes]
        ids = [ann['question_id'] for ann in anns]
        return ids

    def getImgIds(self, quesIds=[], quesTypes=[], ansTypes=[]):
        """
        Get image ids that satisfy given filter conditions. default skips that filter
        :param quesIds   (int array)   : get image ids for given question ids
               quesTypes (str array)   : get image ids for given question types
               ansTypes  (str array)   : get image ids for given answer types
        :return: ids     (int array)   : integer array of image ids
        """
        quesIds = quesIds if type(quesIds) == list else [quesIds]
        quesTypes = quesTypes if type(quesTypes) == list else [quesTypes]
        ansTypes = ansTypes if type(ansTypes) == list else [ansTypes]

        if len(quesIds) == len(quesTypes) == len(ansTypes) == 0:
            anns = self.dataset['annotations']
        else:
            if not len(quesIds) == 0:
                anns = sum([[self.qa[quesId]] for quesId in quesIds if quesId in self.qa], [])
            else:
                anns = self.dataset['annotations']
            anns = anns if len(quesTypes) == 0 else [ann for ann in anns if ann['question_type'] in quesTypes]
            anns = anns if len(ansTypes) == 0 else [ann for ann in anns if ann['answer_type'] in ansTypes]
        ids = [ann['image_id'] for ann in anns]
        return ids

    def loadQA(self, ids=[]):
        """
        Load answers with the specified question ids.
        :param ids (int array)       : integer ids specifying question ids
        :return: qa (object array)   : loaded qa objects
        """
        if type(ids) == list:
            return [self.qa[id] for id in ids]
        elif type(ids) == int:
            return [self.qa[ids]]

    def loadQQA(self, ids=[]):
        """
        Load questions with the specified question ids.
        :param ids (int array)       : integer ids specifying question ids
        :return: qa (object array)   : loaded qa objects
        """
        if type(ids) == list:
            return [self.qqa[id] for id in ids]
        elif type(ids) == int:
            return [self.qqa[ids]]

    def showQA(self, anns):
        """
        Display the specified annotations.
        :param anns (array of object): annotations to display
        :return: None
        """
        if len(anns) == 0:
            return 0
        for ann in anns:
            quesId = ann['question_id']
            print("Question: %s" % (self.qqa[quesId]['question']))
            for ans in ann['answers']:
                print("Answer %d: %s" % (ans['answer_id'], ans['answer']))

    def loadRes(self, resFile, quesFile):
        """
        Load result file and return a result object.
        :param   resFile (str)     : file name of result file
        :return: res (obj)         : result api object
        """
        res = VQA()
        res.questions = json.load(open(quesFile))
        res.dataset['info'] = copy.deepcopy(self.questions['info'])
        res.dataset['task_type'] = copy.deepcopy(self.questions['task_type'])
        res.dataset['data_type'] = copy.deepcopy(self.questions['data_type'])
        res.dataset['data_subtype'] = copy.deepcopy(self.questions['data_subtype'])
        res.dataset['license'] = copy.deepcopy(self.questions['license'])

        print('Loading and preparing results...     ')
        time_t = datetime.datetime.utcnow()
        anns = json.load(open(resFile))
        assert type(anns) == list, 'results is not an array of objects'
        annsQuesIds = [ann['question_id'] for ann in anns]
        assert set(annsQuesIds) == set(self.getQuesIds()), \
            'Results do not correspond to current VQA set. Either the results do not have predictions for all question ids in annotation file or there is atleast one question id that does not belong to the question ids in the annotation file.'
        for ann in anns:
            quesId = ann['question_id']
            if res.dataset['task_type'] == 'Multiple Choice':
                assert ann['answer'] in self.qqa[quesId][
                    'multiple_choices'], 'predicted answer is not one of the multiple choices'
            qaAnn = self.qa[quesId]
            ann['image_id'] = qaAnn['image_id']
            ann['question_type'] = qaAnn['question_type']
            ann['answer_type'] = qaAnn['answer_type']
        print('DONE (t=%0.2fs)' % ((datetime.datetime.utcnow() - time_t).total_seconds()))

        res.dataset['annotations'] = anns
        res.createIndex()
        return res

# %%
def pil_loader(path): # PIL Loader is simply RGB
    # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
    with open(path, 'rb') as f:
        img = Image.open(f)
        img = img.convert('RGB')
    return img


def default_loader(path): # accimage loader is faster but does not have all operations as PIL, uses intel IPP library
    from torchvision import get_image_backend
    if get_image_backend() == 'accimage':
        return accimage_loader(path)
    else:
        return pil_loader(path)


def pre_process_val(image_dir, qjson, ajson, img_prefix):
    with open('/content/drive/MyDrive/VQA/a2i.pkl', 'rb') as f:
        a2i = pickle.load(f)
        # print('a2i is ', a2i)

    vqa = VQA(ajson, qjson)

    img_names = [f for f in os.listdir(image_dir) if '.jpg' in f]
    img_ids = []
    for fname in img_names:
        img_id = fname.split('.')[0].rpartition(img_prefix)[-1]
        img_ids.append(int(img_id))

    ques_ids = vqa.getQuesIds(img_ids)

    ques_ids_modif = []
    for ques_id in ques_ids:
        qa = vqa.loadQA(ques_id)[0]
        qqa = vqa.loadQQA(ques_id)[0]

        ques = qqa['question'][:-1]
        answers = qa['answers']
        answer = ""
        for ans in answers:
            ans = ans['answer'].lower()
            if ans in a2i:
                answer = ans
                break

        if not answer == "":
            ques_ids_modif.append(ques_id)
    return ques_ids_modif, img_names, img_ids


def pre_process_dataset2(image_dir, qjson, ajson, img_prefix):
    print('Preprocessing datatset method #2. \n')
    vqa = VQA(ajson, qjson)

    img_names = [f for f in os.listdir(image_dir) if '.jpg' in f]
    img_ids = []
    for fname in img_names:
        img_id = fname.split('.')[0].rpartition(img_prefix)[-1]
        img_ids.append(int(img_id))

    ques_ids = vqa.getQuesIds(img_ids)

    q2i = defaultdict(lambda: len(q2i))
    pad = q2i["<pad>"]
    start = q2i["<sos>"]
    end = q2i["<eos>"]
    UNK = q2i["<unk>"]

    a2i_count = {}
    for ques_id in ques_ids:
        qa = vqa.loadQA(ques_id)[0]  # [0] means all answers for a question id, array has already one item
        qqa = vqa.loadQQA(ques_id)[0]  # [0] means question

        ques = qqa['question'][:-1]
        [q2i[x] for x in ques.lower().strip().split(" ")]

        answers = qa['answers']
        for ans in answers:
            if not ans['answer_confidence'] == 'yes':
                continue
            ans = ans['answer'].lower()
            if ans not in a2i_count:
                a2i_count[ans] = 1
            else:
                a2i_count[ans] = a2i_count[ans] + 1

    a_sort = sorted(a2i_count.items(), key=operator.itemgetter(1), reverse=True)

    i2a = {}
    count = 0
    a2i = defaultdict(lambda: len(a2i))
    for word, _ in a_sort:
        a2i[word]
        i2a[a2i[word]] = word
        count = count + 1
        if count == 1000:
            break

    ques_ids_modif = []
    for ques_id in ques_ids:
        qa = vqa.loadQA(ques_id)[0]
        qqa = vqa.loadQQA(ques_id)[0]

        ques = qqa['question'][:-1]
        answers = qa['answers']
        answer = ""
        for ans in answers:
            ans = ans['answer'].lower()
            if ans in a2i:
                answer = ans
                break

        if answer == "":
            continue
        ques_ids_modif.append(ques_id)
    return q2i, a2i, i2a, a2i_count, ques_ids_modif, ques_ids, img_names, img_ids


def pre_process_dataset(image_dir, qjson, ajson, img_prefix):
    print('Preprocessing datatset. \n')
    vqa = VQA(ajson, qjson)

    img_names = [f for f in os.listdir(image_dir) if '.jpg' in f]
    img_ids = []
    for fname in img_names:
        img_id = fname.split('.')[0].rpartition(img_prefix)[-1]
        img_ids.append(int(img_id))

    # print('img_ids is', img_ids)
    ques_ids = vqa.getQuesIds(img_ids)
    # global q2i
    q2i = defaultdict(lambda: len(q2i))  # default for non-existant key will be len(q2i)
    pad = q2i["<pad>"]
    # print('pad is ', pad)
    # print('length of q2i is ', len(q2i))
    start = q2i["<sos>"]
    # print('start is ', start)
    # print('length of q2i is ', len(q2i))
    end = q2i["<eos>"]
    # print('end is ', end)
    # print('length of q2i is ', len(q2i))
    UNK = q2i["<unk>"]
    # print('UNK is ', UNK)
    # print('length of q2i is ', len(q2i))

    # global a2i_count
    a2i_count = {}
    for ques_id in ques_ids:
        qa = vqa.loadQA(ques_id)[0]
        # print('qa is ', qa)
        qqa = vqa.loadQQA(ques_id)[0]
        # print('qqa is ', qqa)
        """
        qa is  {
            'question_type': 'are the', 
            'multiple_choice_answer': 'no', 
            'answers': [
                {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1}, 
                {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2}, 
                {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3}, 
                {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4}, 
                {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5}, 
                {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6}, 
                {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7}, 
                {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8}, 
                {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9}, 
                {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}
            ], 
            'image_id': 225041, 
            'answer_type': 'yes/no', 
            'question_id': 225041000
        }
        qqa is  {
            'image_id': 225041, 
            'question': 'Are the people getting off the bus?', 
            'question_id': 225041000
        }
        """
        ques = qqa['question'][:-1]  # -1 to omit the last character from the ques which is the question mark ?
        # print('ques is ', ques)
        [q2i[x] for x in ques.lower().strip().split(" ")]  # q2i contains each word existing in a question, each one with an index.

        """
        q2i length is  15196
        ('<pad>', 0)
        ('<sos>', 1)
        ('<eos>', 2)
        ('<unk>', 3)
        ('is', 4)
        ('the', 5)
        ('player', 6)
        ('left', 7)
        ('or', 8)
        ('right', 9)
        """
        answers = qa['answers']
        for ans in answers:
            if not ans['answer_confidence'] == 'yes':
                continue
            ans = ans['answer'].lower()
            if ans not in a2i_count:
                a2i_count[ans] = 1
            else:
                a2i_count[ans] = a2i_count[ans] + 1

    a_sort = sorted(a2i_count.items(), key=operator.itemgetter(1), reverse=True)
    # print('sorted answer length is ', len(a_sort))
    # print('sorted answers by occurance is ')
    # for x in range(10):#len(a_sort)):
    # print(a_sort[x])

    """
    sorted answer length is  120299
    sorted answers by occurance is 
    ('no', 720451)
    ('yes', 704532)
    ('1', 108698)
    ('2', 108314)
    ('white', 71814)
    ('3', 51803)
    ('red', 43869)
    ('blue', 41489)
    ('black', 39940)
    ('0', 39628)
    """

    # global i2a
    i2a = {}
    count = 0
    # global a2i
    a2i = defaultdict(lambda: len(a2i))
    for word, _ in a_sort:
        a2i[ word]  # put each answer from the a_sort in a defaultdict a2i with len(a2i) which means each new word gets an iterative index because the words does not exist already
        i2a[a2i[ word]] = word  # make a copy list i2a similar to the a2i so putting each answer with an index sorted to the frequency of the answer
        count = count + 1
        if count == 1000:
            break
    """
    a2i length is  1000
    ('no', 0)
    ('yes', 1)
    ('1', 2)
    ('2', 3)
    ('white', 4)
    ('3', 5)
    ('red', 6)
    ('blue', 7)
    ('black', 8)
    ('0', 9)

    i2a length is  1000
    (0, 'no')
    (1, 'yes')
    (2, '1')
    (3, '2')
    (4, 'white')
    (5, '3')
    (6, 'red')
    (7, 'blue')
    (8, 'black')
    (9, '0')
    """
    print('a2i length is ', len(a2i))
    iterator = iter(a2i.items())
    for i in range(10):
        print(next(iterator))

    # for item in a2i.items():
    #    print(item)
    print('i2a length is ', len(i2a))
    iterator = iter(i2a.items())
    for i in range(10):
        print(next(iterator))
    # for item in i2a.items():
    #    print(item)
    print('q2i length is ', len(q2i))
    iterator = iter(q2i.items())
    for i in range(10):
        print(next(iterator))
    # for item in q2i.items():
    #    print(item)
    print('a2i_count length is ', len(a2i_count))
    iterator = iter(a2i_count.items())
    for i in range(10):
        print(next(iterator))
    # for item in a2i_count.items():
    #    print(item)
    return q2i, a2i, i2a, a2i_count


def collate_lines(seq_list):
    imgT, quesT, gT = zip(*seq_list)
    lens = [len(ques) for ques in quesT]
    seq_order = sorted(range(len(lens)), key=lens.__getitem__, reverse=True)
    imgT = torch.stack([imgT[i] for i in seq_order])
    quesT = [quesT[i] for i in seq_order]
    gT = torch.stack([gT[i] for i in seq_order])
    return imgT, quesT, gT

# %%
 # !pip install sentencepiece
 # !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.8/dist-packages (0.1.97)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: simpletransformers in /usr/local/lib/python3.8/dist-packages (0.63.9)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (1.7.3)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (2.11.2)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (2.25.1)
# Requirement already satisfied: transformers>=4.6.0 in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (4.26.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (1.3.5)
# Requirement already satisfied: datasets in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (2.9.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (0.1.97)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (1.21.6)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (1.18.1)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (0.13.2)
# Requirement already satisfied: wandb>=0.10.32 in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (0.13.10)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (1.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers>=4.6.0->simpletransformers) (3.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.6.0->simpletransformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.6.0->simpletransformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.6.0->simpletransformers) (0.12.0)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.8/dist-packages (from wandb>=0.10.32->simpletransformers) (0.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from wandb>=0.10.32->simpletransformers) (4.4.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.8/dist-packages (from wandb>=0.10.32->simpletransformers) (7.1.2)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb>=0.10.32->simpletransformers) (3.19.6)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb>=0.10.32->simpletransformers) (1.15.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.8/dist-packages (from wandb>=0.10.32->simpletransformers) (1.3.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from wandb>=0.10.32->simpletransformers) (0.4.0)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.8/dist-packages (from wandb>=0.10.32->simpletransformers) (1.4.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb>=0.10.32->simpletransformers) (57.4.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb>=0.10.32->simpletransformers) (5.4.8)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb>=0.10.32->simpletransformers) (3.1.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->simpletransformers) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->simpletransformers) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->simpletransformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->simpletransformers) (2022.12.7)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.8/dist-packages (from datasets->simpletransformers) (3.2.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets->simpletransformers) (3.8.3)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets->simpletransformers) (0.3.6)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.8/dist-packages (from datasets->simpletransformers) (0.18.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.8/dist-packages (from datasets->simpletransformers) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets->simpletransformers) (2023.1.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets->simpletransformers) (9.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->simpletransformers) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->simpletransformers) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->simpletransformers) (1.2.0)
# Requirement already satisfied: blinker>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (1.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (7.1.2)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (2.2.1)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (1.0.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (6.0.0)
# Requirement already satisfied: semver in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (2.13.0)
# Requirement already satisfied: tornado>=6.0.3 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (6.0.4)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (4.2.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (5.3.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (0.8.0)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (1.5.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: validators>=0.2 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (0.20.0)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (13.3.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorboard->simpletransformers) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->simpletransformers) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->simpletransformers) (1.51.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->simpletransformers) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->simpletransformers) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard->simpletransformers) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard->simpletransformers) (3.4.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->simpletransformers) (2.16.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (4.3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (2.11.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->simpletransformers) (0.4)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.10.32->simpletransformers) (1.15.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->simpletransformers) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->simpletransformers) (22.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->simpletransformers) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->simpletransformers) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->simpletransformers) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->simpletransformers) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets->simpletransformers) (1.3.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from GitPython>=1.0.0->wandb>=0.10.32->simpletransformers) (4.0.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=1.4->streamlit->simpletransformers) (3.12.1)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in /usr/local/lib/python3.8/dist-packages (from rich>=10.11.0->streamlit->simpletransformers) (2.1.0)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from validators>=0.2->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb>=0.10.32->simpletransformers) (5.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->altair>=3.2.0->streamlit->simpletransformers) (2.0.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers) (5.10.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->simpletransformers) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.8/dist-packages (from markdown-it-py<3.0.0,>=2.1.0->rich>=10.11.0->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->simpletransformers) (3.2.2)

# %%
#import transformers
#from transformers import BertTokenizer, BertModel
#from transformers import DebertaTokenizerFast
from transformers import XLMRobertaTokenizer, XLMRobertaModel
#from transformers import RobertaTokenizer, RobertaModel
#tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
#tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
#tokenizer = DebertaTokenizerFast.from_pretrained("microsoft/deberta-base")
tokenizer = XLMRobertaTokenizer.from_pretrained("xlm-roberta-large")
#model = BertModel.from_pretrained("bert-large-uncased")
class VqaDataset(Dataset):
    """
    Load the VQA dataset using the VQA python API. We provide the necessary subset in the External folder, but you may
    want to reference the full repo (https://github.com/GT-Vision-Lab/VQA) for usage examples.
    """

    def __init__(self, image_dir, question_json_file_path, annotation_json_file_path,
                 image_filename_pattern, collate=False, q2i=None, a2i=None, i2a=None,
                 a2i_count=None, img_names=None, img_ids=None, ques_ids=None,
                 method='simple', dataset_type='train', enc_dir=''):
        """
        Args:
            image_dir (string): Path to the directory with COCO images
            question_json_file_path (string): Path to the json file containing the question data
            annotation_json_file_path (string): Path to the json file containing the annotations mapping images, questions, and
                answers together
            image_filename_pattern (string): The pattern the filenames of images in this dataset use (eg "COCO_train2014_{}.jpg")
        """

        print('inside VqaDataset')
        print('Method is ', method)
        self.image_dir = image_dir
        self.qjson = question_json_file_path
        self.ajson = annotation_json_file_path
        img_prefix = image_filename_pattern.split('{}')[0]#img_prefix=COCO_train2014_
        self.collate = collate
        self.q2i = q2i
        self.a2i = a2i
        self.i2a = i2a
        self.a2i_count = a2i_count
        self.img_ids = img_ids
        self.ques_ids = ques_ids
        self.img_names = img_names
        self.method = method
        self.vqa = VQA(self.ajson, self.qjson)

        if self.method == 'simple':
            self.transform = transforms.Compose([transforms.Resize((224, 224)), transforms.ToTensor()])
        else:
            self.transform = transforms.Compose([transforms.Resize((448, 448)), transforms.ToTensor()])

        if not collate:
            print('not collate')
            self.img_names = [f for f in os.listdir(self.image_dir) if '.jpg' in f] # Get the image name: list form
            self.img_ids = [] #for:img_ids is full of pictures id:000000000001-nnnnnnnnn
            for fname in self.img_names: #fname = "COC0_train2014_000000000009. jpg"
                img_id = fname.split('.')[0].rpartition(img_prefix)[-1] #img_id =000000000009 (string type)
                self.img_ids.append(int(img_id))

            self.ques_ids = self.vqa.getQuesIds(self.img_ids)

            self.q2i, self.a2i, self.i2a, self.a2i_count = pre_process_dataset(image_dir, self.qjson, self.ajson, img_prefix)
            #print('length of q2i is ', len(q2i), 'of folder ' , image_dir)
            #print('length of a2i is ', len(a2i), 'of folder ' , image_dir)
            #print('length of i2a is ', len(i2a), 'of folder ' , image_dir)
            #print('length of a2i_count is ', len(a2i_count), 'of folder ' , image_dir)

        self.q2i_len = len(self.q2i)
        self.a2i_len = len(self.a2i.keys())
        self.q2i_keys = self.q2i.keys() #Get the keys of q2i, q2i: {"where": 0, "is":1, "he":2, "looking":3}), that is, get where, is, he, looking. . .
        self.enc_dir = enc_dir
        #print('length of q2i is ', len(q2i), 'of folder ', image_dir)
        #print('length of a2i is ', len(a2i), 'of folder ', image_dir)
        #print('length of i2a is ', len(i2a), 'of folder ', image_dir)
        #print('length of a2i_count is ', len(a2i_count), 'of folder ', image_dir)

        if collate and dataset_type == 'train':
            print('collate and train')
            with open('/content/drive/MyDrive/VQA/train_enc_idx.npy', 'rb') as f:
                self.enc_idx = pickle.load(f)
        elif collate and dataset_type == 'val':
            print('collate and val')
            with open('/content/drive/MyDrive/VQA/val_enc_idx.npy', 'rb') as f:
                self.enc_idx = pickle.load(f)

    def __len__(self):
        return len(self.ques_ids)

    def __getitem__(self, idx):
        ques_id = self.ques_ids[idx]
        #print('ques_id is ',ques_id)
        img_id = self.vqa.getImgIds([ques_id])[0]
        #print('img_id is ', img_id)

        qa = self.vqa.loadQA(ques_id)[0]
        qqa = self.vqa.loadQQA(ques_id)[0]
        img_name = self.img_names[self.img_ids.index(img_id)]

        if self.method == 'simple':
            img = default_loader(self.image_dir + '/' + img_name)
            #imgT = self.transform(img).permute(1, 2, 0)
            imgT = self.transform(img).float()
        else:
            #file_idx = self.enc_idx[img_id] // 50
            #arr_idx = self.enc_idx[img_id] % 50
            #path = self.enc_dir + '/' + str(file_idx) + '.npz'
            #img = np.load(path)['out'][arr_idx, :, :]               # 512 x 196
            #imgT = torch.from_numpy(img).float()

            img = default_loader(self.image_dir + '/' + img_name)
            imgT = self.transform(img).float()
            #print('image tensor size after transform is ', imgT.size())

        ques = qqa['question'][:-1] #Get the question with the question mark removed
        #ques_BERT = '[CLS] ' + ques + ' [SEP]'
        ques_BERT = ques
        #tokens = tokenizer.tokenize(ques_BERT)
        tokens = tokenizer(ques_BERT)
        #print('tokens is ', tokens['input_ids'])
        #indexes = tokenizer.convert_tokens_to_ids(tokens['input_ids'])
        indexes = (tokens['input_ids'])
        
        #print('ques is ', ques)
        """
        ques = '[CLS] ' + ques + ' [SEP] '
        #print('ques is ', ques)
        #print('length of tokenizer is ', len(tokenizer))
        tokens = tokenizer.tokenize(ques)
        #print(tokens)
        cls_token = tokenizer.cls_token
        sep_token = tokenizer.sep_token
        pad_token = tokenizer.pad_token
        unk_token = tokenizer.unk_token
        #print(cls_token, sep_token, pad_token, unk_token)
        cls_token_idx = tokenizer.cls_token_id
        sep_token_idx = tokenizer.sep_token_id
        pad_token_idx = tokenizer.pad_token_id
        unk_token_idx = tokenizer.unk_token_id
        #print(cls_token_idx, sep_token_idx, pad_token_idx, unk_token_idx)
        indexes = tokenizer.convert_tokens_to_ids(tokens)
        #print('indexes are ', indexes)
        encoded_input = tokenizer(ques, return_tensors='pt')
        #print('encoded inout is ', encoded_input['input_ids'])
        output = model(**encoded_input)
        #print('output is ', output['last_hidden_state'].size())
        """
        quesI = [self.q2i["<sos>"]] + [self.q2i[x.lower()] for x in ques.split(" ") if x.lower() in self.q2i_keys] + [self.q2i["<eos>"]]
        # q2i={dict:11471}, q2i={"<pad>':0,'<sos>':1,'<eos>':2,'<unk>':3, 'what':4, 'color':5. . . }
        # quesI = [1,4,454,54,843,6,11,2]
        if not self.collate:
            quesI = quesI + [self.q2i["<pad>"]]*(8 - len(quesI)) #????? why 8? What if the question len(quesI greater than 8)
        if self.method == 'simple':
            quesT = torch.zeros(self.q2i_len).float()#quesT:tensor([0. ,1. ,1. ,. . 0.0.0])
            for idx in quesI:
                quesT[idx] = 1
        else:
            quesT = torch.tensor([indexes]).squeeze(0)
            #quesT = torch.from_numpy(np.array(quesI)).long()
            #quesT = output['last_hidden_state'].squeeze(0)
            #print('inside get_item, quesT is ', quesT)
            #print('inside get item, questT size is ', quesT.size())

        answers = qa['answers']
        max_count = 0
        answer = ""
        for ans in answers:
            #if not ans['answer_confidence'] == 'yes': # try running it with this condition enabled
            #    continue
            ans = ans['answer'].lower()
            if ans in self.a2i.keys() and self.a2i_count[ans] > max_count: # ans has to be in the top 1000 a2i.keys
                max_count = self.a2i_count[ans]
                answer = ans # take the answer of the question as the most dominant answer in the a2i_count dict
                #print('answer is ', answer)
        #print('the chosen answer is ', answer)

        if answer == "":                                              # only for validation
            gT = torch.from_numpy(np.array([self.a2i_len])).long()
        else:
            gT = torch.from_numpy(np.array([self.a2i[answer]])).long()

        if not self.collate:
            return {'img' : imgT, 'ques' : quesT, 'gt': gT}

        return imgT, quesT, gT

# %%
class VqaImgDataset(Dataset):

    def __init__(self, image_dir, name, img_prefix):
        self.image_dir = image_dir
        self.img_names = [f for f in os.listdir(self.image_dir) if '.jpg' in f]
        self.transform = transforms.Compose([transforms.Resize((448, 448)),
                                             transforms.ToTensor()])

        img_ids = {}
        for idx, fname in enumerate(self.img_names):
            img_id = fname.split('.')[0].rpartition(img_prefix)[-1]
            img_ids[int(img_id)] = idx

        with open('/content/drive/MyDrive/VQA/' + name + '_enc_idx.npy', 'wb') as f:
            pickle.dump(img_ids, f)

    def __len__(self):
        return len(self.img_names)

    def __getitem__(self, idx):
        img = default_loader(self.image_dir + '/' + self.img_names[idx])
        imgT = self.transform(img)

        return imgT.float()

# %%
#from transformers import BertModel,DistilBertModel,DebertaModel
class CoattentionNet(nn.Module):
    """
    Predicts an answer to a question about an image using the Hierarchical Question-Image Co-Attention
    for Visual Question Answering (Lu et al, 2017) paper.
    """
    def __init__(self, num_embeddings, num_classes, embed_dim=1024, k=30):#num_embeddings = len(q2i), num_classes = 1000, why embed_dim is 512?
        super().__init__()
        print('inside model')
        self.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
        if self.DEVICE == "cuda":
            print('Device is cuda')
        # nn. Embedding: The input is a list of numbers, and the output is a list of corresponding symbol embedding vectors
        # num_embeddings: The size of the dictionary, for example, if there are 5000 words in total, then enter 5000
        # embed_dim: The dimension of the input vector, that is, how many dimensions are used to represent a symbol
        #self.embed = nn.Embedding(num_embeddings, embed_dim) # len(q2i) number of rows for words, 512 vector length or the number of columns
                                    #    512,      512 kernel size
        #print('question embedding weight is ', self.embed.weight)
        #model1 = gensim.models.Word2Vec(data, min_count = 1, vector_size = 512, window = 5)
        #with torch.no_grad():
        #self.bert_model = BertModel.from_pretrained('bert-base-uncased', output_hidden_states = True,)
        #self.bert_model = RobertaModel.from_pretrained('roberta-base', output_hidden_states = True,)
        #self.bert_model = DebertaModel.from_pretrained("microsoft/deberta-base", output_hidden_states = True,)
        self.bert_model = XLMRobertaModel.from_pretrained("xlm-roberta-large", output_hidden_states = True,)
        #self.bert_model.eval()
        self.unigram_conv = nn.Conv1d(embed_dim, embed_dim, 1, stride=1, padding=0)
        self.bigram_conv  = nn.Conv1d(embed_dim, embed_dim, 2, stride=1, padding=1, dilation=2) #bigram means each KS=2
        # so each word will be convoluted twice, for the first and last word to be convoulted twice means we need an extra 1 word padding on each side
        # padding is usually kernel -1 # why dilation is 2? try with dilation = 1
        self.trigram_conv = nn.Conv1d(embed_dim, embed_dim, 3, stride=1, padding=2, dilation=2)# same as above trigram
        # so KS=3 and stride 1 means each word will be convoluted three times, for each word to be convoluted three times then we need 2 extra padding on each side
        self.max_pool = nn.MaxPool2d((3, 1)) # kernel =3,1 which is equivalent to 3 rows and 1 column to get the max value of each word t in question q
        # Maximum pooling layer: The maximum pool is used in this article to obtain phrase-level characteristics
        # After maximum pooling, lstm is used to encode the sequence problem phrase level, and the corresponding problem-level feature qst is the hidden vector of time tLSTM.
        self.lstm = nn.LSTM(input_size=embed_dim, hidden_size=embed_dim, num_layers=3, dropout=0.4) # "Vanilla LSTM" 3 layers
        # mean single input layer, single hidden layer and single output layer
        self.tanh = nn.Tanh()
        self.W_b = nn.Parameter(torch.randn(embed_dim, embed_dim))
        self.W_v = nn.Parameter(torch.randn(k, embed_dim))
        self.W_q = nn.Parameter(torch.randn(k, embed_dim))
        self.w_hv = nn.Parameter(torch.randn(k, 1))
        self.w_hq = nn.Parameter(torch.randn(k, 1))

        #self.W_w = nn.Parameter(torch.randn(embed_dim, embed_dim))
        #self.W_p = nn.Parameter(torch.randn(embed_dim*2, embed_dim))
        #self.W_s = nn.Parameter(torch.randn(embed_dim*2, embed_dim))

        self.W_w = nn.Linear(embed_dim, embed_dim)
        self.W_p = nn.Linear(embed_dim*2, embed_dim)
        self.W_s = nn.Linear(embed_dim*2, embed_dim) # why Ws for sentence or question is not embed_dim*3?

        self.fc = nn.Linear(embed_dim, num_classes)

    def forward(self, image, question):                    # Image: B x 512 x 196 # is the question here passed after
        # one-hot-encoding? question is a long tensor of 8 long numbers representing the question words
        #print('question type is ', type(question))
        #print('inside forward')
        #print('question is ', question)
        #print('image is ', image)
        #print('image size is ', image.size())
        ####print('question size is ', question.size())
        #print('sorted tensors by length')
        #print(sorted(question, key=lambda x: x.size()[0], reverse=True))
        question, lens = rnn.pad_packed_sequence(question)
        #print('question after padding is ', question)
        #print('question after padding size is ', question.size())
        question = question.permute(1, 0)                  # Ques : B x L where B stands for batch and batch is 100
        #print('question after permute is ', question)
        #print('question after permute size is ', question.size())
        #      question after permute size is  torch.Size([100, 17])
        #words = self.embed(question).permute(0, 2, 1)      # Words: B x L x 512
        segments_ids = []
        for i in range(len(question)):
          segments_ids.append([1]*len(question[0]))
        
        for x in range(len(question)):
          for y in range(len(question[0])):
            if (question[x][y] == 0):
              segments_ids[x][y] = 0
        
        segments_tensors = torch.tensor(segments_ids)
        segments_tensors = segments_tensors.to(self.DEVICE)
        token_type_ids = []
        for i in range(len(question)):
          token_type_ids.append([0]*len(question[0]))
        token_type_ids_tensors = torch.tensor(token_type_ids)
        token_type_ids_tensors = token_type_ids_tensors.to(self.DEVICE)

        #print('segments_tensors is ', segments_tensors)
        self.bert_model.eval()
        with torch.no_grad():          
          #self.bert_model = BertModel.from_pretrained('bert-base-uncased', output_hidden_states = True,)
          words_c = self.bert_model(question,segments_tensors, token_type_ids_tensors)
          words = words_c['last_hidden_state'].permute(0, 2, 1)
        #print('words is ', words)
        #print('words size is ', words.size())
        """
          words = []
          for z in range(len(question)):
            index = torch.tensor([z]).to(self.DEVICE)
            question_z = torch.index_select(question, 0, index).to(self.DEVICE)
            segments_tensors_z = torch.index_select(segments_tensors, 0, index).to(self.DEVICE)
            words.append(self.bert_model(question_z,segments_tensors_z)['last_hidden_state'].permute(0, 2, 1))
          #words = torch.tensor(words).to(self.DEVICE)
          print('words is ', words)
          #print('words size is ', words.size())
          
          indices = torch.tensor([0]).to(self.DEVICE)
          #print('first question is ', torch.index_select(question, 0, indices))

          question1 = torch.index_select(question, 0, indices).to(self.DEVICE)
          print('question1 is ', question1)
          segments_tensors1 = torch.index_select(segments_tensors, 0, indices).to(self.DEVICE)
          token_type_ids_tensors1 = torch.index_select(token_type_ids_tensors, 0, indices).to(self.DEVICE)
          print('segments_tensors1 is ', segments_tensors1)
          words_c1 = self.bert_model(question1,segments_tensors1)#, token_type_ids_tensors1)
          words1 = words_c1['last_hidden_state'].permute(0, 2, 1)
          print('words1 is ', words1)
          print('words1 size is ', words1.size())
        """  
        #delete from here
        #words = self.embed(question)
        #print('words size is ', words.size())
        #words = words.permute(0,2,1)
        #print('words size after permute is ', words.size())
        # till here

        #torch.set_printoptions(profile="full")
        #print('words is ', words)
        #print('words after embed and permute size is ', words.size())
        #print('words is ', words)

        #      words after embed and permute size is torch.Size([100, 512, 13])
        #unigrams size is torch.Size([100, 512, 1, 13])
        #bigrams size is torch.Size([100, 512, 1, 13])
        #trigrams size is torch.Size([100, 512, 1, 13])

        unigrams = torch.unsqueeze(self.tanh(self.unigram_conv(words)), 2) # B x 512 x L
        #print('unigrams size is ', unigrams.size())
        bigrams  = torch.unsqueeze(self.tanh(self.bigram_conv(words)), 2)  # B x 512 x L
        #print('bigrams size is ', bigrams.size())
        trigrams = torch.unsqueeze(self.tanh(self.trigram_conv(words)), 2) # B x 512 x L
        #print('trigrams size is ', trigrams.size())
        words = words.permute(0, 2, 1)
        #print('words after convolution and unsqueeze and permute size is ', words.size())
        #      words after convolution and unsqueeze and permute size is  torch.Size([100, 13, 512])

        #phrase = torch.squeeze(self.max_pool(torch.cat((unigrams, bigrams, trigrams), 2)))
        phrase = torch.cat((unigrams, bigrams, trigrams),2)
        #print('phrase after torch cat size is ', phrase.size())
        phrase= self.max_pool(phrase)
        #print('phrase after maxpool size is ', phrase.size())
        #print('phrase is ', phrase)
        phrase = torch.squeeze(phrase)
        #print('phrase after squeeze and before permute size is ', phrase.size())
        #print('phrase is ', phrase)
        phrase = phrase.permute(0, 2, 1)                                    # B x L x 512
        #print('phrase after permute size is ', phrase.size())

        hidden = None
        phrase_packed = nn.utils.rnn.pack_padded_sequence(torch.transpose(phrase, 0, 1), lens)
        sentence_packed, hidden = self.lstm(phrase_packed, hidden)
        sentence, _ = rnn.pad_packed_sequence(sentence_packed)
        sentence = torch.transpose(sentence, 0, 1)                          # B x L x 512

        #print('image tensor size is ', image.size())
        #print('question tensor size is ', words.size())
        #print('phrase tensor size is ', phrase.size())
        #print('sentence tensor size is ', sentence.size())
        #image = F.pad(input=image, pad=(0, 0, 0, 256), mode='constant', value=0)
        image = F.pad(input=image, pad=(0, 0, 256, 256), mode='constant', value=0)
        v_word, q_word = self.parallel_co_attention(image, words)
        #print('v_word size is ', v_word.size())
        #print('q_word size is ', q_word.size())
        v_phrase, q_phrase = self.parallel_co_attention(image, phrase)
        #print('v_phrase size is ', v_phrase.size())
        #print('q_phrase size is ', q_phrase.size())
        v_sent, q_sent = self.parallel_co_attention(image, sentence)
        #print('v_sent size is ', v_sent.size())
        #print('q_sent size is ', v_sent.size())

        #h_w = self.tanh(torch.matmul((q_word + v_word), self.W_w))
        #h_p = self.tanh(torch.matmul(torch.cat(((q_phrase + v_phrase), h_w), dim=1), self.W_p))
        #h_s = self.tanh(torch.matmul(torch.cat(((q_sent + v_sent), h_p), dim=1), self.W_s))

        h_w = self.tanh(self.W_w(q_word + v_word))
        #print('h_w size is ', h_w.size())
        h_p = self.tanh(self.W_p(torch.cat(((q_phrase + v_phrase), h_w), dim=1)))
        #print('h_p size is ', h_p.size())
        h_s = self.tanh(self.W_s(torch.cat(((q_sent + v_sent), h_p), dim=1)))
        #print('h_s size is ', h_s.size())

        logits = self.fc(h_s)
        #print('logits has type of ', type(logits))
        #print('size of logits is ', logits.size())
        #print('first prediction is ')

        return logits

    def parallel_co_attention(self, V, Q):  # V : B x 512 x 196, Q : B x L x 512
        C = torch.matmul(Q, torch.matmul(self.W_b, V)) # B x L x 196

        H_v = self.tanh(torch.matmul(self.W_v, V) + torch.matmul(torch.matmul(self.W_q, Q.permute(0, 2, 1)), C))                            # B x k x 196
        H_q = self.tanh(torch.matmul(self.W_q, Q.permute(0, 2, 1)) + torch.matmul(torch.matmul(self.W_v, V), C.permute(0, 2, 1)))           # B x k x L

        #a_v = torch.squeeze(fn.softmax(torch.matmul(torch.t(self.w_hv), H_v), dim=2)) # B x 196
        #a_q = torch.squeeze(fn.softmax(torch.matmul(torch.t(self.w_hq), H_q), dim=2)) # B x L

        a_v = fn.softmax(torch.matmul(torch.t(self.w_hv), H_v), dim=2) # B x 1 x 196
        a_q = fn.softmax(torch.matmul(torch.t(self.w_hq), H_q), dim=2) # B x 1 x L

        v = torch.squeeze(torch.matmul(a_v, V.permute(0, 2, 1))) # B x 512
        q = torch.squeeze(torch.matmul(a_q, Q))                  # B x 512

        return v, q

# %%
class ExperimentRunnerBase(object):
    """
    This base class contains the simple train and validation loops for your VQA experiments.
    Anything specific to a particular experiment (Simple or Coattention) should go in the corresponding subclass.
    """

    def __init__(self, train_dataset, val_dataset, model, batch_size, num_epochs, num_data_loader_workers=10, lr=0.001):
        self._model = model
        self._num_epochs = num_epochs
        self._log_freq = 100             # Steps
        self._test_freq = 250*4         # Steps
        self._save_freq = 1 #2          # Epochs
        self._print_freq = 50
        self._batch_size = batch_size
        self._lr = lr
        print('Inside ExperminetRunnerBase Constructor')

        # Use the GPU if it's available.
        self.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
        if self.DEVICE == "cuda":
            print('Device is cuda')
            self._model = self._model.cuda()

        if self.method == 'simple':
            #self.optimizer = optim.Adam(self._model.parameters(), lr=self._lr)
            #self.optimizer = optim.SGD([{'params': self._model.embed.parameters(), 'lr': 0.8},
            #                            {'params': self._model.gnet.parameters(), 'lr': 1e-2},
            #                            {'params': self._model.fc.parameters(), 'lr': 1e-2}
            #                           ], momentum=0.9)
            self.optimizer = optim.Adam([{'params': self._model.embed.parameters(), 'lr': 0.08},
                                        {'params': self._model.gnet.parameters(), 'lr': 1e-3},
                                        {'params': self._model.fc.parameters(), 'lr': 1e-3}
                                       ], weight_decay=1e-8)
        else:
            self.optimizer = optim.Adam(self._model.parameters(), lr=self._lr, weight_decay=1e-8)
        self.criterion = nn.CrossEntropyLoss()
        self.initialize_weights()

        #Logger for tensorboard
        self.writer = SummaryWriter()

        self.total_validation_questions = 214354.0 #121512.0

        if self.method == 'simple':
            self.chk_dir = '/content/drive/MyDrive/VQA/chk_simple/'
        else:
            self.chk_dir = '/content/drive/MyDrive/VQA/chk_coattention/'
            print('Creating Image Encoder')
            self.img_enc = models.resnet34(pretrained=True)
            modules = list(self.img_enc.children())[:-2] # resnet feature extractor, all layer except last 2 or from layer 0 to layer 7, can use [0:8] which means 0 --> 7
            self.img_enc = nn.Sequential(*modules)
            for params in self.img_enc.parameters():
                params.requires_grad = False
            if self.DEVICE == "cuda":
                self.img_enc = self.img_enc.cuda()
            self.img_enc.eval()

        if not os.path.exists(self.chk_dir):
            os.makedirs(self.chk_dir)

    def _optimize(self, predicted_answers, true_answers):
        """
        This gets implemented in the subclasses. Don't implement this here.
        """
        raise NotImplementedError()


    def validate(self):
        # TODO. Should return your validation accuracy
        accuracy = 0.0
        for batch_id, (imgT, quesT, gT) in enumerate(self._val_dataset_loader):
            self._model.eval()  # Set the model to train mode

            if not self.method == 'simple':
                quesT = rnn.pack_sequence(quesT)
                #print('1- image tensor size is ', imgT.size())
                imgT = imgT.to(self.DEVICE)
                #print('2- image tensor size is ', imgT.size())
                imgT = self.img_enc(imgT)
                #print('3- image tensor size is ', imgT.size())
                imgT = imgT.view(imgT.size(0), imgT.size(1), -1)
                #print('4- image tensor size is ', imgT.size())

            imgT, quesT, gT = imgT.to(self.DEVICE), quesT.to(self.DEVICE), gT.to(self.DEVICE)
            gT = torch.squeeze(gT)
            #torch.set_printoptions(profile="full")
            #print('validating')
            #print('image tensor size is ', imgT.size())
            #print('image tensor is ', imgT)
            #print('question tensor size is ', quesT.size())
            #print('question tensor is ', quesT)
            #print('ground truth tensor size is ', gT.size())
            #print('question tensor is ', quesT)
            pd_ans = self._model(imgT, quesT) # TODO
            #print('pd_ans size is ', pd_ans.size())
            for i in range(gT.shape[0]):
                if torch.argmax(pd_ans[i]).item() == gT[i]:
                    #print('matching answers. Predicted is ', torch.argmax(pd_ans[i]).item(), ' and ground truth is ', gT[i].item())
                    accuracy = accuracy + 1.0
                #else:
                    #print('not matching answers. Predicted is ', torch.argmax(pd_ans[i]).item(), ' and ground truth is ', gT[i].item()) 

            if (batch_id + 1) % self._print_freq == 0:
                print('Validation Accuracy: %f' % (accuracy / ((batch_id + 1)*self._batch_size)))
        print('number of accurate answers is ', accuracy, ' out of the total number of validation questions ' , self.total_validation_questions)
        accuracy = accuracy / self.total_validation_questions
        print('accuracy % is ', accuracy * 100)
        return accuracy

    def train(self):
        print('Started Training.\n')
        tr_iter = 0
        val_iter = 0
        best_prec = 0.0
        for epoch in range(self._num_epochs):
            if (epoch + 1) // 3 == 0:
                print('epoch is ', epoch)
                self.adjust_learning_rate(epoch + 1)
            num_batches = len(self._train_dataset_loader)
            #print('num_batches is ', num_batches)
            for batch_id, (imgT, quesT, gT) in enumerate(self._train_dataset_loader):
                #print('batch id is ', batch_id)
                self._model.train()  # Set the model to train mode
                current_step = epoch * num_batches + batch_id

                # ============
                # TODO: Run the model and get the ground truth answers that you'll pass to your optimizer
                # This logic should be generic; not specific to either the Simple Baseline or CoAttention.
                if not self.method == 'simple':
                    #print('quesT is ', quesT)
                    #print('quesT rows is ', len(quesT))
                    #print('quesT column is ', len(quesT[0]))
                    #print('questT type is ', type(quesT))
                    #print('packing quesT')
                    quesT = rnn.pack_sequence(quesT)
                    #print('done packing quesT')
                    #print('1- image tensor size is ', imgT.size())
                    imgT = imgT.to(self.DEVICE)
                    #print('2- image tensor size is ', imgT.size())
                    imgT = self.img_enc(imgT)
                    #print('3- image tensor size is ', imgT.size())
                    imgT = imgT.view(imgT.size(0), imgT.size(1), -1)
                    #print('4- image tensor size is ', imgT.size())

                    """
                    1- image tensor size is  torch.Size([100, 3, 448, 448])
                    2- image tensor size is  torch.Size([100, 3, 448, 448])
                    3- image tensor size is  torch.Size([100, 512, 14, 14])
                    4- image tensor size is  torch.Size([100, 512, 196])
                    """
                else:
                    imgT = imgT.to(self.DEVICE)

                quesT, gT = quesT.to(self.DEVICE), gT.to(self.DEVICE)
                predicted_answer = self._model(imgT, quesT) # TODO
                #print('predicted answer size is ', predicted_answer.size())
                ground_truth_answer = torch.squeeze(gT)     # TODO
                # ============

                # Optimize the model according to the predictions
                loss = self._optimize(predicted_answer, ground_truth_answer)

                if (current_step + 1) % self._log_freq == 0:
                    now = datetime.now()
                    current_time = now.strftime("%H:%M:%S")
                    print("Time: ", current_time, " Epoch: {}, Batch {}/{} has loss {}".format(epoch, batch_id, num_batches, loss))

                    # TODO: you probably want to plot something here
                    self.writer.add_scalar('train/loss', loss.item(), tr_iter)
                    tr_iter = tr_iter + 1

#                if (current_step + 1) % self._test_freq == 0:
#                    self._model.eval()
#                    val_accuracy = self.validate()
#                    print("Epoch: {} has val accuracy {}".format(epoch, val_accuracy))
#
#                    # TODO: you probably want to plot something here
#                    self.writer.add_scalar('valid/accuracy', val_accuracy, val_iter)
#                    val_iter = val_iter + 1
            #print('will be saving checkpoint at ', self.chk_dir + 'checkpoint_' + str(epoch + 1) + '.pth.tar')
            if (epoch + 1) % self._save_freq == 0 or epoch == self._num_epochs - 1:
                val_accuracy = self.validate()
                print("Epoch: {} has val accuracy {}".format(epoch, val_accuracy))
                self.writer.add_scalar('valid/accuracy', val_accuracy, val_iter)
                val_iter = val_iter + 1

                # remember best val_accuracy and save checkpoint
                is_best = val_accuracy > best_prec
                best_prec = max(val_accuracy, best_prec)
                print('saving checkpoint at ', self.chk_dir + 'checkpoint_' + str(epoch + 1) + '.pth.tar')
                torch.save(self._model.state_dict(), self.chk_dir + 'checkpoint_' + str(epoch + 1) + '_Ahmed_1024_new_XLMBERTa.pth.tar')
                self.save_checkpoint({'epoch': epoch + 1,
                                      'state_dict': self._model.state_dict(),
                                      'best_prec': best_prec},
                                      #'optimizer': optimizer.state_dict()}, is_best,
                                      is_best, self.chk_dir + 'checkpoint_' + str(epoch + 1) + '.pth.tar')

        # Closing tensorboard logger
        logdir = os.path.join('./tb_', datetime.now().strftime('%Y-%m-%d_%H-%M-%S'))
        if not os.path.exists(logdir):
            os.makedirs(logdir)
        self.writer.export_scalars_to_json(logdir + 'tb_summary.json')
        self.writer.close()

    def initialize_weights(self):
      for layer in self._model.modules():
          if not isinstance(layer, (nn.Conv2d, nn.Linear)):
              continue
          try:
              torch.nn.init.xavier_normal_(layer.weight)
              try:
                  nn.init.constant_(layer.bias.data, 0)
              except:
                  pass
          except:
              pass

    def save_checkpoint(self, state, is_best, filename='checkpoint.pth.tar'):
        torch.save(state, filename)
        if is_best:
            shutil.copyfile(filename, 'model_best.pth.tar')

    def adjust_learning_rate(self, epoch):
        """Sets the learning rate to the initial LR decayed by 10 every 5 epochs"""
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = param_group['lr'] / 10

# %%
class CoattentionNetExperimentRunner(ExperimentRunnerBase):
    """
    Sets up the Co-Attention model for training. This class is specifically responsible for creating the model and optimizing it.
    """
    def __init__(self, train_image_dir, train_question_path, train_annotation_path,
                 test_image_dir, test_question_path,test_annotation_path, batch_size, num_epochs,
                 num_data_loader_workers):

        self.method = 'coattention'
        print('Loading coattention numpy files. \n')
        with open('/content/drive/MyDrive/VQA/q2i.pkl', 'rb') as f:
            q2i = pickle.load(f)
        with open('/content/drive/MyDrive/VQA/a2i.pkl', 'rb') as f:
            a2i = pickle.load(f)
        with open('/content/drive/MyDrive/VQA/i2a.pkl', 'rb') as f:
            i2a = pickle.load(f)
        with open('/content/drive/MyDrive/VQA/a2i_count.pkl', 'rb') as f:
            a2i_count = pickle.load(f)

        #print('length of imported q2i.pkl is ', len(q2i))
        #print('length of imported a2i.pkl is ', len(a2i))
        #print('length of imported i2a.pkl is ', len(i2a))
        #print('length of imported a2i_count.pkl is ', len(a2i_count))

        tr_img_names = np.load('/content/drive/MyDrive/VQA/tr_img_names.npy', encoding='latin1').tolist()
        tr_img_ids = np.load('/content/drive/MyDrive/VQA/tr_img_ids.npy', encoding='latin1').tolist()
        tr_ques_ids = np.load('/content/drive/MyDrive/VQA/tr_ques_ids.npy', encoding='latin1').tolist()

        va_img_names = np.load('/content/drive/MyDrive/VQA/va_img_names.npy', encoding='latin1').tolist()
        va_img_ids = np.load('/content/drive/MyDrive/VQA/va_img_ids.npy', encoding='latin1').tolist()
        va_ques_ids = np.load('/content/drive/MyDrive/VQA/va_ques_ids.npy', encoding='latin1').tolist()
        
        ######va_ques_ids = np.load('va_ques_ids_orig.npy', encoding='latin1').tolist()

        #va_img_names = np.load('/content/drive/MyDrive/VQA/tr_img_names.npy', encoding='latin1').tolist()
        #va_img_ids = np.load('/content/drive/MyDrive/VQA/tr_img_ids.npy', encoding='latin1').tolist()
        #va_ques_ids = np.load('/content/drive/MyDrive/VQA/tr_ques_ids.npy', encoding='latin1').tolist()

        print('Creating Datasets.')
        train_dataset = VqaDataset(image_dir=train_image_dir, collate=True,
                                   question_json_file_path=train_question_path,
                                   annotation_json_file_path=train_annotation_path,
                                   image_filename_pattern="COCO_train2014_{}.jpg",
                                   q2i=q2i, a2i=a2i, i2a=i2a, a2i_count=a2i_count,
                                   img_names=tr_img_names, img_ids=tr_img_ids,
                                   ques_ids=tr_ques_ids, method=self.method,
                                   dataset_type="train", enc_dir='tr_enc')

        val_dataset = VqaDataset(image_dir=test_image_dir, collate=True,
                                 question_json_file_path=test_question_path,
                                 annotation_json_file_path=test_annotation_path,
                                 image_filename_pattern="COCO_val2014_{}.jpg",
                                 q2i=q2i, a2i=a2i, i2a=i2a, a2i_count=a2i_count,
                                 img_names=va_img_names, img_ids=va_img_ids,
                                 ques_ids=va_ques_ids, method=self.method,
                                 dataset_type="validation", enc_dir='va_enc')

        """val_dataset = VqaDataset(image_dir=train_image_dir, collate=True,
                                   question_json_file_path=train_question_path,
                                   annotation_json_file_path=train_annotation_path,
                                   image_filename_pattern="COCO_train2014_{}.jpg",
                                   q2i=q2i, a2i=a2i, i2a=i2a, a2i_count=a2i_count,
                                   img_names=tr_img_names, img_ids=tr_img_ids,
                                   ques_ids=tr_ques_ids, method=self.method,
                                   dataset_type="train", enc_dir='tr_enc')"""

        self._train_dataset_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=10, collate_fn=collate_lines)

        self._val_dataset_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=10, collate_fn=collate_lines)


        print('Creating Co Attention Model.')
        model = CoattentionNet(len(q2i), 1000).float()

        super().__init__(train_dataset, val_dataset, model, batch_size, num_epochs, num_data_loader_workers)


    def _optimize(self, predicted_answers, true_answer_ids):
        self.optimizer.zero_grad()
        loss = self.criterion(predicted_answers, true_answer_ids)
        loss.backward()
        self.optimizer.step()

        return loss

# %%
from torch.utils import model_zoo

__all__ = ['GoogLeNet', 'googlenet']

model_urls = {
    # GoogLeNet ported from TensorFlow
    'googlenet': 'https://download.pytorch.org/models/googlenet-1378be20.pth',
}


def googlenet(pretrained=False, **kwargs):
    r"""GoogLeNet (Inception v1) model architecture from
    `"Going Deeper with Convolutions" <http://arxiv.org/abs/1409.4842>`_.
    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        transform_input (bool): If True, preprocesses the input according to the method with which it was trained on ImageNet. Default: *False*
    """
    if pretrained:
        if 'transform_input' not in kwargs:
            kwargs['transform_input'] = True
        kwargs['init_weights'] = False
        model = GoogLeNet(**kwargs)
        model.load_state_dict(model_zoo.load_url(model_urls['googlenet']))
        return model

    return GoogLeNet(**kwargs)

# %%
class BasicConv2d(nn.Module):

    def __init__(self, in_channels, out_channels, **kwargs):
        super(BasicConv2d, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
        self.bn = nn.BatchNorm2d(out_channels, eps=0.001)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        return F.relu(x, inplace=True)


class GoogLeNet(nn.Module):

    def __init__(self, num_classes=1000, aux_logits=True, transform_input=False,
                       init_weights=True, remove_fc=False):
        super(GoogLeNet, self).__init__()
        self.aux_logits = aux_logits
        self.transform_input = transform_input

        self.conv1 = BasicConv2d(3, 64, kernel_size=7, stride=2, padding=3)
        self.maxpool1 = nn.MaxPool2d(3, stride=2, ceil_mode=True)
        self.conv2 = BasicConv2d(64, 64, kernel_size=1)
        self.conv3 = BasicConv2d(64, 192, kernel_size=3, padding=1)
        self.maxpool2 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception3a = Inception(192, 64, 96, 128, 16, 32, 32)
        self.inception3b = Inception(256, 128, 128, 192, 32, 96, 64)
        self.maxpool3 = nn.MaxPool2d(3, stride=2, ceil_mode=True)

        self.inception4a = Inception(480, 192, 96, 208, 16, 48, 64)
        self.inception4b = Inception(512, 160, 112, 224, 24, 64, 64)
        self.inception4c = Inception(512, 128, 128, 256, 24, 64, 64)
        self.inception4d = Inception(512, 112, 144, 288, 32, 64, 64)
        self.inception4e = Inception(528, 256, 160, 320, 32, 128, 128)
        self.maxpool4 = nn.MaxPool2d(2, stride=2, ceil_mode=True)

        self.inception5a = Inception(832, 256, 160, 320, 32, 128, 128)
        self.inception5b = Inception(832, 384, 192, 384, 48, 128, 128)
        if aux_logits:
            self.aux1 = InceptionAux(512, num_classes)
            self.aux2 = InceptionAux(528, num_classes)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        self.remove_fc = remove_fc
        self.dropout = nn.Dropout(0.4)
        self.fc = nn.Linear(1024, num_classes)

        if init_weights:
            self._initialize_weights()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.xavier_uniform_(m.weight)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0.2)
            elif isinstance(m, nn.Linear):
                nn.init.xavier_uniform_(m.weight)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        if self.transform_input:
            x_ch0 = torch.unsqueeze(x[:, 0], 1) * (0.229 / 0.5) + (0.485 - 0.5) / 0.5
            x_ch1 = torch.unsqueeze(x[:, 1], 1) * (0.224 / 0.5) + (0.456 - 0.5) / 0.5
            x_ch2 = torch.unsqueeze(x[:, 2], 1) * (0.225 / 0.5) + (0.406 - 0.5) / 0.5
            x = torch.cat((x_ch0, x_ch1, x_ch2), 1)

        # N x 3 x 224 x 224
        x = self.conv1(x)
        # N x 64 x 112 x 112
        x = self.maxpool1(x)
        # N x 64 x 56 x 56
        x = self.conv2(x)
        # N x 64 x 56 x 56
        x = self.conv3(x)
        # N x 192 x 56 x 56
        x = self.maxpool2(x)

        # N x 192 x 28 x 28
        x = self.inception3a(x)
        # N x 256 x 28 x 28
        x = self.inception3b(x)
        # N x 480 x 28 x 28
        x = self.maxpool3(x)
        # N x 480 x 14 x 14
        x = self.inception4a(x)
        # N x 512 x 14 x 14
        if self.training and self.aux_logits and not self.remove_fc:
            aux1 = self.aux1(x)

        x = self.inception4b(x)
        # N x 512 x 14 x 14
        x = self.inception4c(x)
        # N x 512 x 14 x 14
        x = self.inception4d(x)
        # N x 528 x 14 x 14
        if self.training and self.aux_logits and not self.remove_fc:
            aux2 = self.aux2(x)

        x = self.inception4e(x)
        # N x 832 x 14 x 14
        x = self.maxpool4(x)
        # N x 832 x 7 x 7
        x = self.inception5a(x)
        # N x 832 x 7 x 7
        x = self.inception5b(x)
        # N x 1024 x 7 x 7

        x = self.avgpool(x)
        # N x 1024 x 1 x 1
        x = x.view(x.size(0), -1)

        if not self.remove_fc:
            # N x 1024
            x = self.dropout(x)
            x = self.fc(x)

        # N x 1000 (num_classes)
        if self.training and self.aux_logits and not self.remove_fc:
            return aux1, aux2, x

        return x


class Inception(nn.Module):

    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()

        self.branch1 = BasicConv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            BasicConv2d(in_channels, ch3x3red, kernel_size=1),
            BasicConv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)
        )

        self.branch3 = nn.Sequential(
            BasicConv2d(in_channels, ch5x5red, kernel_size=1),
            BasicConv2d(ch5x5red, ch5x5, kernel_size=3, padding=1)
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1, ceil_mode=True),
            BasicConv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        branch1 = self.branch1(x)
        branch2 = self.branch2(x)
        branch3 = self.branch3(x)
        branch4 = self.branch4(x)

        outputs = [branch1, branch2, branch3, branch4]
        return torch.cat(outputs, 1)


class InceptionAux(nn.Module):

    def __init__(self, in_channels, num_classes):
        super(InceptionAux, self).__init__()
        self.conv = BasicConv2d(in_channels, 128, kernel_size=1)

        self.fc1 = nn.Linear(2048, 1024)
        self.fc2 = nn.Linear(1024, num_classes)

    def forward(self, x):
        # aux1: N x 512 x 14 x 14, aux2: N x 528 x 14 x 14
        x = F.adaptive_avg_pool2d(x, (4, 4))
        # aux1: N x 512 x 4 x 4, aux2: N x 528 x 4 x 4
        x = self.conv(x)
        # N x 128 x 4 x 4
        x = x.view(x.size(0), -1)
        # N x 2048
        x = F.relu(self.fc1(x), inplace=True)
        # N x 2048
        x = F.dropout(x, 0.7, training=self.training)
        # N x 2048
        x = self.fc2(x)
        # N x 1024

        return x

# %%
class SimpleBaselineNet(nn.Module):
    """
    Predicts an answer to a question about an image using the Simple Baseline for Visual Question Answering (Zhou et al, 2017) paper.
    """
    def __init__(self, num_embeddings, num_classes):
        super().__init__()

        self.gnet = googlenet(pretrained=True, remove_fc=True)
        #self.embed = nn.Embedding(num_embeddings, 1024)
        self.embed = nn.Linear(num_embeddings, 1024)
        self.fc = nn.Linear(1024 + 1024, num_classes)

    def forward(self, image, question_encoding):
        img = self.gnet(image)
        ques = self.embed(question_encoding)

        con = torch.cat((img, ques), dim=1)
        return self.fc(con)


class SimpleBaselineExperimentRunner(ExperimentRunnerBase):
    """
    Sets up the Simple Baseline model for training. This class is specifically responsible for creating the model and optimizing it.
    """
    def __init__(self, train_image_dir, train_question_path, train_annotation_path,
                 test_image_dir, test_question_path,test_annotation_path, batch_size, num_epochs,
                 num_data_loader_workers):
        print('inside SimpleBaseLineExperimentRunner')
        self.method = 'simple'
        print('Loading simple numpy files. \n')
        with open('q2i.pkl', 'rb') as f:
            q2i = pickle.load(f)
        with open('a2i.pkl', 'rb') as f:
            a2i = pickle.load(f)
        with open('i2a.pkl', 'rb') as f:
            i2a = pickle.load(f)
        with open('a2i_count.pkl', 'rb') as f:
            a2i_count = pickle.load(f)

        tr_img_names = np.load('tr_img_names.npy', encoding='latin1').tolist()
        tr_img_ids = np.load('tr_img_ids.npy', encoding='latin1').tolist()
        tr_ques_ids = np.load('tr_ques_ids.npy', encoding='latin1').tolist()

        va_img_names = np.load('va_img_names.npy', encoding='latin1').tolist()
        va_img_ids = np.load('va_img_ids.npy', encoding='latin1').tolist()
        va_ques_ids = np.load('va_ques_ids.npy', encoding='latin1').tolist()
        #va_ques_ids = np.load('va_ques_ids_orig.npy', encoding='latin1').tolist()

        #va_ques_ids_complete = np.load('va_ques_ids_orig.npy', encoding='latin1').tolist()
        #print('Total Validation Questions: %d' % len(va_ques_ids_complete))
        #print('Total training validation Questions: %d' % len(va_ques_ids))

        print('Creating Datasets.')
        train_dataset = VqaDataset(image_dir=train_image_dir, collate=True,
                                   question_json_file_path=train_question_path,
                                   annotation_json_file_path=train_annotation_path,
                                   image_filename_pattern="COCO_train2014_{}.jpg",
                                   q2i=q2i, a2i=a2i, i2a=i2a, a2i_count=a2i_count,
                                   img_names=tr_img_names, img_ids=tr_img_ids,
                                   ques_ids=tr_ques_ids, method="simple",
                                   dataset_type="train")

        val_dataset = VqaDataset(image_dir=test_image_dir, collate=True,
                                 question_json_file_path=test_question_path,
                                 annotation_json_file_path=test_annotation_path,
                                 image_filename_pattern="COCO_val2014_{}.jpg",
                                 q2i=q2i, a2i=a2i, i2a=i2a, a2i_count=a2i_count,
                                 img_names=va_img_names, img_ids=va_img_ids,
                                 ques_ids=va_ques_ids, method="simple",
                                 dataset_type="validation")

        self._train_dataset_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=10)#num_data_loader_workers)

        self._val_dataset_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=10)#num_data_loader_workers)


        print('Creating Simple Baseline Model.')
        model = SimpleBaselineNet(len(q2i), 1000).float()

        super().__init__(train_dataset, val_dataset, model, batch_size, num_epochs, num_data_loader_workers)

    def _optimize(self, predicted_answers, true_answer_ids):
        self.optimizer.zero_grad() #optimizer.zero_grad() clears x.grad for every parameter x in the optimizer.
        # It’s important to call this before loss.backward(), otherwise you’ll accumulate the gradients from multiple passes.
        loss = self.criterion(predicted_answers, true_answer_ids) #criterion is CrossEntropyLoss
        loss.backward() #loss.backward() computes dloss/dx for every parameter x
        self.optimizer.step() #optimizer.step updates the value of x using the gradient x.grad

        return loss

# %%
import torch
torch.cuda.empty_cache()

# %%
#from google.colab import drive
#drive.mount('/content/drive/')

# %%
if __name__ == '__main__':

    image_dir = "/content/drive/MyDrive/VQA/train2014"
    img_prefix = "COCO_train2014_"
    qjson = "/content/drive/MyDrive/VQA/v2_OpenEnded_mscoco_train2014_questions.json"
    ajson = "/content/drive/MyDrive/VQA/v2_mscoco_train2014_annotations.json"
    parser = argparse.ArgumentParser(description='Load VQA.')
    parser.add_argument('--model', type=str, choices=['simple', 'coattention'], default='coattention')
    parser.add_argument('--train_image_dir', type=str, default='/content/drive/MyDrive/VQA/train2014')
    parser.add_argument('--train_question_path', type=str, default='/content/drive/MyDrive/VQA/v2_OpenEnded_mscoco_train2014_questions.json')
    parser.add_argument('--train_annotation_path', type=str, default='/content/drive/MyDrive/VQA/v2_mscoco_train2014_annotations.json')
    
    parser.add_argument('--test_image_dir', type=str, default='/content/drive/MyDrive/VQA/val2014')
    parser.add_argument('--test_question_path', type=str, default='/content/drive/MyDrive/VQA/v2_OpenEnded_mscoco_val2014_questions.json')
    parser.add_argument('--test_annotation_path', type=str, default='/content/drive/MyDrive/VQA/v2_mscoco_val2014_annotations.json')

    #parser.add_argument('--test_image_dir', type=str, default='/content/drive/MyDrive/VQA/train2014')
    #parser.add_argument('--test_question_path', type=str, default='/content/drive/MyDrive/VQA/v2_OpenEnded_mscoco_train2014_questions.json')
    #parser.add_argument('--test_annotation_path', type=str, default='/content/drive/MyDrive/VQA/v2_mscoco_train2014_annotations.json')
    
    parser.add_argument('--batch_size', type=int, default=25)
    parser.add_argument('--num_epochs', type=int, default=15)
    parser.add_argument('--num_data_loader_workers', type=int, default=10)
    #print('Kokowawa-8')
    #args = parser.parse_args()
    args, unknown = parser.parse_known_args()

    if args.model == "simple":
        experiment_runner_class = SimpleBaselineExperimentRunner
    elif args.model == "coattention":
        experiment_runner_class = CoattentionNetExperimentRunner
    else:
        raise ModuleNotFoundError()

    experiment_runner = experiment_runner_class(train_image_dir=args.train_image_dir,
                                                train_question_path=args.train_question_path,
                                                train_annotation_path=args.train_annotation_path,
                                                test_image_dir=args.test_image_dir,
                                                test_question_path=args.test_question_path,
                                                test_annotation_path=args.test_annotation_path,
                                                batch_size=args.batch_size,
                                                num_epochs=args.num_epochs,
                                                num_data_loader_workers=args.num_data_loader_workers)
    experiment_runner.train()
# Out:
# Loading coattention numpy files.
#
# Creating Datasets.
# inside VqaDataset
# Method is  coattention
# loading VQA annotations and questions into memory...
# 0:00:11.339225
# creating index...
# index created!
# collate and train
# inside VqaDataset
# Method is  coattention
# loading VQA annotations and questions into memory...
# 0:00:04.964690
# creating index...
# index created!
# Creating Co Attention Model.
# inside model
# Device is cuda
# Some weights of the model checkpoint at xlm-roberta-large were not used when initializing XLMRobertaModel: ['lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight']
# - This IS expected if you are initializing XLMRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Inside ExperminetRunnerBase Constructor
# Device is cuda
# Creating Image Encoder
# Started Training.
#
# epoch is  0
# Time:  06:13:37  Epoch: 0, Batch 99/16894 has loss 3.224860191345215
# Time:  06:13:49  Epoch: 0, Batch 199/16894 has loss 3.674711227416992
# Time:  06:14:02  Epoch: 0, Batch 299/16894 has loss 3.251924991607666
# Time:  06:14:15  Epoch: 0, Batch 399/16894 has loss 2.719611883163452
# Time:  06:14:27  Epoch: 0, Batch 499/16894 has loss 2.2607498168945312
# Time:  06:14:39  Epoch: 0, Batch 599/16894 has loss 2.4494593143463135
# Time:  06:14:52  Epoch: 0, Batch 699/16894 has loss 2.723775625228882
# Time:  06:15:05  Epoch: 0, Batch 799/16894 has loss 3.4918551445007324
# Time:  06:15:17  Epoch: 0, Batch 899/16894 has loss 3.6034786701202393
# Time:  06:15:29  Epoch: 0, Batch 999/16894 has loss 3.23921537399292
# Time:  06:15:42  Epoch: 0, Batch 1099/16894 has loss 3.135361433029175
# Time:  06:15:54  Epoch: 0, Batch 1199/16894 has loss 3.3970718383789062
# Time:  06:16:06  Epoch: 0, Batch 1299/16894 has loss 2.40191912651062
# Time:  06:16:19  Epoch: 0, Batch 1399/16894 has loss 2.7652781009674072
# Time:  06:16:31  Epoch: 0, Batch 1499/16894 has loss 3.6397626399993896
# Time:  06:16:44  Epoch: 0, Batch 1599/16894 has loss 2.062685012817383
# Time:  06:16:56  Epoch: 0, Batch 1699/16894 has loss 2.7065513134002686
# Time:  06:17:08  Epoch: 0, Batch 1799/16894 has loss 2.711416006088257
# Time:  06:17:21  Epoch: 0, Batch 1899/16894 has loss 2.446188449859619
# Time:  06:17:33  Epoch: 0, Batch 1999/16894 has loss 2.1892447471618652
# Time:  06:17:46  Epoch: 0, Batch 2099/16894 has loss 2.886554479598999
# Time:  06:17:58  Epoch: 0, Batch 2199/16894 has loss 2.148181200027466
# Time:  06:18:10  Epoch: 0, Batch 2299/16894 has loss 2.192193031311035
# Time:  06:18:22  Epoch: 0, Batch 2399/16894 has loss 2.8627707958221436
# Time:  06:18:35  Epoch: 0, Batch 2499/16894 has loss 3.476341962814331
# Time:  06:18:47  Epoch: 0, Batch 2599/16894 has loss 1.915071964263916
# Time:  06:19:00  Epoch: 0, Batch 2699/16894 has loss 2.482292413711548
# Time:  06:19:12  Epoch: 0, Batch 2799/16894 has loss 2.9599411487579346
# Time:  06:19:24  Epoch: 0, Batch 2899/16894 has loss 2.0738883018493652
# Time:  06:19:36  Epoch: 0, Batch 2999/16894 has loss 2.788759708404541
# Time:  06:19:49  Epoch: 0, Batch 3099/16894 has loss 1.5460132360458374
# Time:  06:20:01  Epoch: 0, Batch 3199/16894 has loss 2.4585494995117188
# Time:  06:20:13  Epoch: 0, Batch 3299/16894 has loss 2.809138774871826
# Time:  06:20:25  Epoch: 0, Batch 3399/16894 has loss 2.2796943187713623
# Time:  06:20:38  Epoch: 0, Batch 3499/16894 has loss 2.855299949645996
# Time:  06:20:50  Epoch: 0, Batch 3599/16894 has loss 2.417512893676758
# Time:  06:21:02  Epoch: 0, Batch 3699/16894 has loss 2.351628303527832
# Time:  06:21:14  Epoch: 0, Batch 3799/16894 has loss 2.7645187377929688
# Time:  06:21:27  Epoch: 0, Batch 3899/16894 has loss 2.613929510116577
# Time:  06:21:39  Epoch: 0, Batch 3999/16894 has loss 1.835330605506897
# Time:  06:21:51  Epoch: 0, Batch 4099/16894 has loss 2.0027573108673096
# Time:  06:22:03  Epoch: 0, Batch 4199/16894 has loss 2.7441611289978027
# Time:  06:22:15  Epoch: 0, Batch 4299/16894 has loss 1.6320292949676514
# Time:  06:22:28  Epoch: 0, Batch 4399/16894 has loss 2.5592870712280273
# Time:  06:22:40  Epoch: 0, Batch 4499/16894 has loss 1.771482229232788
# Time:  06:22:52  Epoch: 0, Batch 4599/16894 has loss 3.294917345046997
# Time:  06:23:05  Epoch: 0, Batch 4699/16894 has loss 2.6017913818359375
# Time:  06:23:17  Epoch: 0, Batch 4799/16894 has loss 3.2529075145721436
# Time:  06:23:29  Epoch: 0, Batch 4899/16894 has loss 2.087524652481079
# Time:  06:23:41  Epoch: 0, Batch 4999/16894 has loss 2.428537607192993
# Time:  06:23:54  Epoch: 0, Batch 5099/16894 has loss 2.371999502182007
# Time:  06:24:06  Epoch: 0, Batch 5199/16894 has loss 1.910231113433838
# Time:  06:24:18  Epoch: 0, Batch 5299/16894 has loss 2.386129856109619
# Time:  06:24:30  Epoch: 0, Batch 5399/16894 has loss 2.4576618671417236
# Time:  06:24:42  Epoch: 0, Batch 5499/16894 has loss 2.0430052280426025
# Time:  06:24:55  Epoch: 0, Batch 5599/16894 has loss 2.7230618000030518
# Time:  06:25:07  Epoch: 0, Batch 5699/16894 has loss 2.8255083560943604
# Time:  06:25:19  Epoch: 0, Batch 5799/16894 has loss 2.386337995529175
# Time:  06:25:32  Epoch: 0, Batch 5899/16894 has loss 2.8647286891937256
# Time:  06:25:44  Epoch: 0, Batch 5999/16894 has loss 2.368807792663574
# Time:  06:25:56  Epoch: 0, Batch 6099/16894 has loss 2.5366170406341553
# Time:  06:26:08  Epoch: 0, Batch 6199/16894 has loss 2.0099711418151855
# Time:  06:26:20  Epoch: 0, Batch 6299/16894 has loss 2.046381950378418
# Time:  06:26:33  Epoch: 0, Batch 6399/16894 has loss 2.460563898086548
# Time:  06:26:45  Epoch: 0, Batch 6499/16894 has loss 2.326730251312256
# Time:  06:26:57  Epoch: 0, Batch 6599/16894 has loss 1.996476411819458
# Time:  06:27:10  Epoch: 0, Batch 6699/16894 has loss 2.454026937484741
# Time:  06:27:22  Epoch: 0, Batch 6799/16894 has loss 2.539419174194336
# Time:  06:27:34  Epoch: 0, Batch 6899/16894 has loss 2.0641367435455322
# Time:  06:27:46  Epoch: 0, Batch 6999/16894 has loss 2.0012407302856445
# Time:  06:27:59  Epoch: 0, Batch 7099/16894 has loss 2.146144151687622
# Time:  06:28:11  Epoch: 0, Batch 7199/16894 has loss 3.1253299713134766
# Time:  06:28:23  Epoch: 0, Batch 7299/16894 has loss 2.4874327182769775
# Time:  06:28:35  Epoch: 0, Batch 7399/16894 has loss 2.0949037075042725
# Time:  06:28:48  Epoch: 0, Batch 7499/16894 has loss 2.0732192993164062
# Time:  06:29:00  Epoch: 0, Batch 7599/16894 has loss 2.2788498401641846
# Time:  06:29:12  Epoch: 0, Batch 7699/16894 has loss 1.7185288667678833
# Time:  06:29:25  Epoch: 0, Batch 7799/16894 has loss 2.2399046421051025
# Time:  06:29:37  Epoch: 0, Batch 7899/16894 has loss 2.3109848499298096
# Time:  06:29:49  Epoch: 0, Batch 7999/16894 has loss 1.886581301689148
# Time:  06:30:01  Epoch: 0, Batch 8099/16894 has loss 3.166659355163574
# Time:  06:30:14  Epoch: 0, Batch 8199/16894 has loss 2.824814796447754
# Time:  06:30:26  Epoch: 0, Batch 8299/16894 has loss 3.112589120864868
# Time:  06:30:38  Epoch: 0, Batch 8399/16894 has loss 2.190659761428833
# Time:  06:30:51  Epoch: 0, Batch 8499/16894 has loss 2.029123306274414
# Time:  06:31:03  Epoch: 0, Batch 8599/16894 has loss 2.311506986618042
# Time:  06:31:15  Epoch: 0, Batch 8699/16894 has loss 2.434537172317505
# Time:  06:31:27  Epoch: 0, Batch 8799/16894 has loss 1.7034765481948853
# Time:  06:31:40  Epoch: 0, Batch 8899/16894 has loss 1.9464013576507568
# Time:  06:31:52  Epoch: 0, Batch 8999/16894 has loss 2.803654670715332
# Time:  06:32:04  Epoch: 0, Batch 9099/16894 has loss 1.8384506702423096
# Time:  06:32:16  Epoch: 0, Batch 9199/16894 has loss 2.648467779159546
# Time:  06:32:29  Epoch: 0, Batch 9299/16894 has loss 2.457526922225952
# Time:  06:32:41  Epoch: 0, Batch 9399/16894 has loss 2.6148290634155273
# Time:  06:32:53  Epoch: 0, Batch 9499/16894 has loss 3.1545042991638184
# Time:  06:33:05  Epoch: 0, Batch 9599/16894 has loss 2.9216458797454834
# Time:  06:33:18  Epoch: 0, Batch 9699/16894 has loss 2.0676684379577637
# Time:  06:33:30  Epoch: 0, Batch 9799/16894 has loss 1.6946731805801392
# Time:  06:33:42  Epoch: 0, Batch 9899/16894 has loss 1.8386579751968384
# Time:  06:33:55  Epoch: 0, Batch 9999/16894 has loss 2.1168534755706787
# Time:  06:34:07  Epoch: 0, Batch 10099/16894 has loss 2.236579179763794
# Time:  06:34:19  Epoch: 0, Batch 10199/16894 has loss 2.2157912254333496
# Time:  06:34:31  Epoch: 0, Batch 10299/16894 has loss 1.9793201684951782
# Time:  06:34:44  Epoch: 0, Batch 10399/16894 has loss 2.266573667526245
# Time:  06:34:56  Epoch: 0, Batch 10499/16894 has loss 2.3173556327819824
# Time:  06:35:09  Epoch: 0, Batch 10599/16894 has loss 2.449226140975952
# Time:  06:35:21  Epoch: 0, Batch 10699/16894 has loss 2.650024175643921
# Time:  06:35:33  Epoch: 0, Batch 10799/16894 has loss 2.2085301876068115
# Time:  06:35:45  Epoch: 0, Batch 10899/16894 has loss 2.692409038543701
# Time:  06:35:58  Epoch: 0, Batch 10999/16894 has loss 2.197045087814331
# Time:  06:36:10  Epoch: 0, Batch 11099/16894 has loss 3.357173442840576
# Time:  06:36:22  Epoch: 0, Batch 11199/16894 has loss 3.0400261878967285
# Time:  06:36:34  Epoch: 0, Batch 11299/16894 has loss 1.9983069896697998
# Time:  06:36:47  Epoch: 0, Batch 11399/16894 has loss 2.1791601181030273
# Time:  06:36:59  Epoch: 0, Batch 11499/16894 has loss 2.277362585067749
# Time:  06:37:11  Epoch: 0, Batch 11599/16894 has loss 2.9104905128479004
# Time:  06:37:24  Epoch: 0, Batch 11699/16894 has loss 1.4517440795898438
# Time:  06:37:36  Epoch: 0, Batch 11799/16894 has loss 1.7041836977005005
# Time:  06:37:48  Epoch: 0, Batch 11899/16894 has loss 1.911738634109497
# Time:  06:38:00  Epoch: 0, Batch 11999/16894 has loss 2.4669530391693115
# Time:  06:38:13  Epoch: 0, Batch 12099/16894 has loss 1.9785206317901611
# Time:  06:38:25  Epoch: 0, Batch 12199/16894 has loss 2.7933173179626465
# Time:  06:38:37  Epoch: 0, Batch 12299/16894 has loss 2.159230947494507
# Time:  06:38:50  Epoch: 0, Batch 12399/16894 has loss 1.4720721244812012
# Time:  06:39:02  Epoch: 0, Batch 12499/16894 has loss 2.315112352371216
# Time:  06:39:29  Epoch: 0, Batch 12599/16894 has loss 2.4546172618865967
# Time:  06:39:42  Epoch: 0, Batch 12699/16894 has loss 2.9725756645202637
# Time:  06:39:54  Epoch: 0, Batch 12799/16894 has loss 2.864917278289795
# Time:  06:40:06  Epoch: 0, Batch 12899/16894 has loss 1.8558872938156128
# Time:  06:40:21  Epoch: 0, Batch 12999/16894 has loss 2.1715312004089355
# Time:  06:40:33  Epoch: 0, Batch 13099/16894 has loss 2.297550916671753
# Time:  06:40:45  Epoch: 0, Batch 13199/16894 has loss 2.2580316066741943
# Time:  06:40:57  Epoch: 0, Batch 13299/16894 has loss 2.0750577449798584
# Time:  06:41:10  Epoch: 0, Batch 13399/16894 has loss 2.418870687484741
# Time:  06:41:22  Epoch: 0, Batch 13499/16894 has loss 2.3203377723693848
# Time:  06:41:34  Epoch: 0, Batch 13599/16894 has loss 1.903783917427063
# Time:  06:41:46  Epoch: 0, Batch 13699/16894 has loss 1.7111042737960815
# Time:  06:41:59  Epoch: 0, Batch 13799/16894 has loss 2.284482002258301
# Time:  06:42:11  Epoch: 0, Batch 13899/16894 has loss 2.637247323989868
# Time:  06:42:23  Epoch: 0, Batch 13999/16894 has loss 3.345365524291992
# Time:  06:42:36  Epoch: 0, Batch 14099/16894 has loss 2.6777966022491455
# Time:  06:42:48  Epoch: 0, Batch 14199/16894 has loss 2.391659736633301
# Time:  06:43:00  Epoch: 0, Batch 14299/16894 has loss 2.005455255508423
# Time:  06:43:13  Epoch: 0, Batch 14399/16894 has loss 2.8528082370758057
# Time:  06:43:25  Epoch: 0, Batch 14499/16894 has loss 2.2346417903900146
# Time:  06:43:37  Epoch: 0, Batch 14599/16894 has loss 2.136007070541382
# Time:  06:43:50  Epoch: 0, Batch 14699/16894 has loss 1.9358773231506348
# Time:  06:44:02  Epoch: 0, Batch 14799/16894 has loss 2.1745336055755615
# Time:  06:44:14  Epoch: 0, Batch 14899/16894 has loss 1.7147538661956787
# Time:  06:44:26  Epoch: 0, Batch 14999/16894 has loss 1.5405573844909668
# Time:  06:44:39  Epoch: 0, Batch 15099/16894 has loss 2.8906798362731934
# Time:  06:44:51  Epoch: 0, Batch 15199/16894 has loss 2.653085947036743
# Time:  06:45:04  Epoch: 0, Batch 15299/16894 has loss 1.8690208196640015
# Time:  06:45:16  Epoch: 0, Batch 15399/16894 has loss 2.2017951011657715
# Time:  06:45:28  Epoch: 0, Batch 15499/16894 has loss 2.793583631515503
# Time:  06:45:40  Epoch: 0, Batch 15599/16894 has loss 2.0461835861206055
# Time:  06:45:53  Epoch: 0, Batch 15699/16894 has loss 1.2143889665603638
# Time:  06:46:05  Epoch: 0, Batch 15799/16894 has loss 2.295559883117676
# Time:  06:46:17  Epoch: 0, Batch 15899/16894 has loss 1.2292450666427612
# Time:  06:46:30  Epoch: 0, Batch 15999/16894 has loss 2.5736284255981445
# Time:  06:46:42  Epoch: 0, Batch 16099/16894 has loss 1.6292784214019775
# Time:  06:46:54  Epoch: 0, Batch 16199/16894 has loss 1.6374534368515015
# Time:  06:47:07  Epoch: 0, Batch 16299/16894 has loss 2.0137088298797607
# Time:  06:47:19  Epoch: 0, Batch 16399/16894 has loss 2.2358767986297607
# Time:  06:47:31  Epoch: 0, Batch 16499/16894 has loss 1.893009901046753
# Time:  06:47:44  Epoch: 0, Batch 16599/16894 has loss 2.692802667617798
# Time:  06:47:56  Epoch: 0, Batch 16699/16894 has loss 2.334242582321167
# Time:  06:48:08  Epoch: 0, Batch 16799/16894 has loss 2.291433811187744
# Validation Accuracy: 0.429600
# Validation Accuracy: 0.449200
# Validation Accuracy: 0.451200
# Validation Accuracy: 0.450200
# Validation Accuracy: 0.454240
# Validation Accuracy: 0.453867
# Validation Accuracy: 0.452686
# Validation Accuracy: 0.452600
# Validation Accuracy: 0.451911
# Validation Accuracy: 0.451600
# Validation Accuracy: 0.451782
# Validation Accuracy: 0.452800
# Validation Accuracy: 0.452000
# Validation Accuracy: 0.452229
# Validation Accuracy: 0.451947
# Validation Accuracy: 0.451000
# Validation Accuracy: 0.451529
# Validation Accuracy: 0.452800
# Validation Accuracy: 0.452126
# Validation Accuracy: 0.451760
# Validation Accuracy: 0.451581
# Validation Accuracy: 0.452036
# Validation Accuracy: 0.451757
# Validation Accuracy: 0.451267
# Validation Accuracy: 0.450656
# Validation Accuracy: 0.450031
# Validation Accuracy: 0.450667
# Validation Accuracy: 0.451371
# Validation Accuracy: 0.451531
# Validation Accuracy: 0.451520
# Validation Accuracy: 0.452955
# Validation Accuracy: 0.452225
# Validation Accuracy: 0.451855
# Validation Accuracy: 0.451718
# Validation Accuracy: 0.451909
# Validation Accuracy: 0.451867
# Validation Accuracy: 0.451286
# Validation Accuracy: 0.451642
# Validation Accuracy: 0.451774
# Validation Accuracy: 0.451700
# Validation Accuracy: 0.452351
# Validation Accuracy: 0.452476
# Validation Accuracy: 0.452167
# Validation Accuracy: 0.452418
# Validation Accuracy: 0.452444
# Validation Accuracy: 0.452591
# Validation Accuracy: 0.452477
# Validation Accuracy: 0.452767
# Validation Accuracy: 0.453110
# Validation Accuracy: 0.452864
# Validation Accuracy: 0.452973
# Validation Accuracy: 0.452954
# Validation Accuracy: 0.453042
# Validation Accuracy: 0.452919
# Validation Accuracy: 0.452553
# Validation Accuracy: 0.452143
# Validation Accuracy: 0.452379
# Validation Accuracy: 0.452414
# Validation Accuracy: 0.452298
# Validation Accuracy: 0.452133
# Validation Accuracy: 0.452105
# Validation Accuracy: 0.452206
# Validation Accuracy: 0.452292
# Validation Accuracy: 0.452363
# Validation Accuracy: 0.452702
# Validation Accuracy: 0.453006
# Validation Accuracy: 0.453087
# Validation Accuracy: 0.452835
# Validation Accuracy: 0.452510
# Validation Accuracy: 0.452457
# Validation Accuracy: 0.452361
# Validation Accuracy: 0.452800
# Validation Accuracy: 0.452822
# Validation Accuracy: 0.452811
# Validation Accuracy: 0.452597
# Validation Accuracy: 0.452253
# Validation Accuracy: 0.451865
# Validation Accuracy: 0.451313
# Validation Accuracy: 0.451180
# Validation Accuracy: 0.451440
# Validation Accuracy: 0.451348
# Validation Accuracy: 0.451376
# Validation Accuracy: 0.451325
# Validation Accuracy: 0.451267
# Validation Accuracy: 0.451388
# Validation Accuracy: 0.451377
# Validation Accuracy: 0.451549
# Validation Accuracy: 0.451582
# Validation Accuracy: 0.451703
# Validation Accuracy: 0.451556
# Validation Accuracy: 0.451455
# Validation Accuracy: 0.451452
# Validation Accuracy: 0.451794
# Validation Accuracy: 0.452068
# Validation Accuracy: 0.452084
# Validation Accuracy: 0.452100
# Validation Accuracy: 0.452066
# Validation Accuracy: 0.451967
# Validation Accuracy: 0.452008
# Validation Accuracy: 0.451936
# Validation Accuracy: 0.451945
# Validation Accuracy: 0.452118
# Validation Accuracy: 0.452085
# Validation Accuracy: 0.452000
# Validation Accuracy: 0.452000
# Validation Accuracy: 0.451917
# Validation Accuracy: 0.452045
# Validation Accuracy: 0.451970
# Validation Accuracy: 0.451831
# Validation Accuracy: 0.451876
# Validation Accuracy: 0.451661
# Validation Accuracy: 0.451700
# Validation Accuracy: 0.451653
# Validation Accuracy: 0.451867
# Validation Accuracy: 0.451923
# Validation Accuracy: 0.452028
# Validation Accuracy: 0.451966
# Validation Accuracy: 0.451980
# Validation Accuracy: 0.451960
# Validation Accuracy: 0.451827
# Validation Accuracy: 0.452040
# Validation Accuracy: 0.452033
# Validation Accuracy: 0.452046
# Validation Accuracy: 0.451942
# Validation Accuracy: 0.451686
# Validation Accuracy: 0.451892
# Validation Accuracy: 0.451628
# Validation Accuracy: 0.451394
# Validation Accuracy: 0.451299
# Validation Accuracy: 0.451262
# Validation Accuracy: 0.451267
# Validation Accuracy: 0.451212
# Validation Accuracy: 0.451194
# Validation Accuracy: 0.451015
# Validation Accuracy: 0.450868
# Validation Accuracy: 0.450965
# Validation Accuracy: 0.451048
# Validation Accuracy: 0.451130
# Validation Accuracy: 0.451108
# Validation Accuracy: 0.451246
# Validation Accuracy: 0.451467
# Validation Accuracy: 0.451397
# Validation Accuracy: 0.451362
# Validation Accuracy: 0.451183
# Validation Accuracy: 0.451360
# Validation Accuracy: 0.451216
# Validation Accuracy: 0.451118
# Validation Accuracy: 0.451000
# Validation Accuracy: 0.451034
# Validation Accuracy: 0.450955
# Validation Accuracy: 0.450803
# Validation Accuracy: 0.450589
# Validation Accuracy: 0.450541
# Validation Accuracy: 0.450618
# Validation Accuracy: 0.450493
# Validation Accuracy: 0.450456
# Validation Accuracy: 0.450380
# Validation Accuracy: 0.450354
# Validation Accuracy: 0.450325
# Validation Accuracy: 0.450365
# Validation Accuracy: 0.450380
# Validation Accuracy: 0.450454
# number of accurate answers is  91731.0  out of the total number of validation questions  214354.0
# accuracy % is  42.79416292674734
# Epoch: 0 has val accuracy 0.4279416292674734
# saving checkpoint at  /content/drive/MyDrive/VQA/chk_coattention/checkpoint_1.pth.tar
# epoch is  1
# Time:  07:04:07  Epoch: 1, Batch 5/16894 has loss 2.496335029602051
# Time:  07:04:19  Epoch: 1, Batch 105/16894 has loss 1.1905817985534668
# Time:  07:04:31  Epoch: 1, Batch 205/16894 has loss 1.6149356365203857
# Time:  07:04:43  Epoch: 1, Batch 305/16894 has loss 1.8530844449996948
# Time:  07:04:56  Epoch: 1, Batch 405/16894 has loss 1.592625379562378
# Time:  07:05:08  Epoch: 1, Batch 505/16894 has loss 3.1231186389923096
# Time:  07:05:21  Epoch: 1, Batch 605/16894 has loss 2.4479761123657227
# Time:  07:05:33  Epoch: 1, Batch 705/16894 has loss 1.850865125656128
# Time:  07:05:45  Epoch: 1, Batch 805/16894 has loss 1.98460054397583
# Time:  07:05:57  Epoch: 1, Batch 905/16894 has loss 1.7896510362625122
# Time:  07:06:09  Epoch: 1, Batch 1005/16894 has loss 2.4408273696899414
# Time:  07:06:22  Epoch: 1, Batch 1105/16894 has loss 1.9575135707855225
# Time:  07:06:34  Epoch: 1, Batch 1205/16894 has loss 1.7694531679153442
# Time:  07:06:46  Epoch: 1, Batch 1305/16894 has loss 2.363476276397705
# Time:  07:06:59  Epoch: 1, Batch 1405/16894 has loss 2.0836265087127686
# Time:  07:07:11  Epoch: 1, Batch 1505/16894 has loss 1.62730073928833
# Time:  07:07:24  Epoch: 1, Batch 1605/16894 has loss 1.4396607875823975
# Time:  07:07:36  Epoch: 1, Batch 1705/16894 has loss 1.5527397394180298
# Time:  07:07:49  Epoch: 1, Batch 1805/16894 has loss 2.119537115097046
# Time:  07:08:01  Epoch: 1, Batch 1905/16894 has loss 1.0483424663543701
# Time:  07:08:14  Epoch: 1, Batch 2005/16894 has loss 1.452974796295166
# Time:  07:08:26  Epoch: 1, Batch 2105/16894 has loss 1.941312313079834
# Time:  07:08:39  Epoch: 1, Batch 2205/16894 has loss 2.011528968811035
# Time:  07:08:51  Epoch: 1, Batch 2305/16894 has loss 2.48870587348938
# Time:  07:09:03  Epoch: 1, Batch 2405/16894 has loss 2.7695369720458984
# Time:  07:09:16  Epoch: 1, Batch 2505/16894 has loss 1.3463234901428223
# Time:  07:09:28  Epoch: 1, Batch 2605/16894 has loss 2.079011917114258
# Time:  07:09:40  Epoch: 1, Batch 2705/16894 has loss 2.2478268146514893
# Time:  07:09:52  Epoch: 1, Batch 2805/16894 has loss 1.8070100545883179
# Time:  07:10:05  Epoch: 1, Batch 2905/16894 has loss 1.4576919078826904
# Time:  07:10:17  Epoch: 1, Batch 3005/16894 has loss 1.9060792922973633
# Time:  07:10:30  Epoch: 1, Batch 3105/16894 has loss 2.4231255054473877
# Time:  07:10:42  Epoch: 1, Batch 3205/16894 has loss 1.6105186939239502
# Time:  07:10:54  Epoch: 1, Batch 3305/16894 has loss 1.554792881011963
# Time:  07:11:06  Epoch: 1, Batch 3405/16894 has loss 1.741734504699707
# Time:  07:11:19  Epoch: 1, Batch 3505/16894 has loss 2.5532174110412598
# Time:  07:11:32  Epoch: 1, Batch 3605/16894 has loss 2.1489598751068115
# Time:  07:11:44  Epoch: 1, Batch 3705/16894 has loss 1.5055650472640991
# Time:  07:11:56  Epoch: 1, Batch 3805/16894 has loss 2.044527053833008
# Time:  07:12:08  Epoch: 1, Batch 3905/16894 has loss 1.6436767578125
# Time:  07:12:21  Epoch: 1, Batch 4005/16894 has loss 1.4470429420471191
# Time:  07:12:33  Epoch: 1, Batch 4105/16894 has loss 2.309919834136963
# Time:  07:12:46  Epoch: 1, Batch 4205/16894 has loss 1.5822579860687256
# Time:  07:12:58  Epoch: 1, Batch 4305/16894 has loss 2.1558988094329834
# Time:  07:13:10  Epoch: 1, Batch 4405/16894 has loss 1.9072154760360718
# Time:  07:13:23  Epoch: 1, Batch 4505/16894 has loss 2.0984554290771484
# Time:  07:13:35  Epoch: 1, Batch 4605/16894 has loss 1.3715617656707764
# Time:  07:13:47  Epoch: 1, Batch 4705/16894 has loss 1.6506266593933105
# Time:  07:14:00  Epoch: 1, Batch 4805/16894 has loss 1.6815955638885498
# Time:  07:14:12  Epoch: 1, Batch 4905/16894 has loss 2.3154711723327637
# Time:  07:14:24  Epoch: 1, Batch 5005/16894 has loss 1.4879660606384277
# Time:  07:14:37  Epoch: 1, Batch 5105/16894 has loss 2.0528953075408936
# Time:  07:14:49  Epoch: 1, Batch 5205/16894 has loss 1.9629627466201782
# Time:  07:15:02  Epoch: 1, Batch 5305/16894 has loss 2.0927541255950928
# Time:  07:15:14  Epoch: 1, Batch 5405/16894 has loss 2.2997303009033203
# Time:  07:15:27  Epoch: 1, Batch 5505/16894 has loss 1.942845344543457
# Time:  07:15:39  Epoch: 1, Batch 5605/16894 has loss 2.1188979148864746
# Time:  07:15:51  Epoch: 1, Batch 5705/16894 has loss 2.115018844604492
# Time:  07:16:04  Epoch: 1, Batch 5805/16894 has loss 2.891031503677368
# Time:  07:16:16  Epoch: 1, Batch 5905/16894 has loss 1.4641823768615723
# Time:  07:16:28  Epoch: 1, Batch 6005/16894 has loss 1.9962331056594849
# Time:  07:16:41  Epoch: 1, Batch 6105/16894 has loss 1.5857588052749634
# Time:  07:16:53  Epoch: 1, Batch 6205/16894 has loss 1.792456030845642
# Time:  07:17:05  Epoch: 1, Batch 6305/16894 has loss 2.5365827083587646
# Time:  07:17:18  Epoch: 1, Batch 6405/16894 has loss 2.020298719406128
# Time:  07:17:30  Epoch: 1, Batch 6505/16894 has loss 1.6689772605895996
# Time:  07:17:43  Epoch: 1, Batch 6605/16894 has loss 1.4422203302383423
# Time:  07:17:55  Epoch: 1, Batch 6705/16894 has loss 1.155966877937317
# Time:  07:18:07  Epoch: 1, Batch 6805/16894 has loss 2.3595986366271973
# Time:  07:18:20  Epoch: 1, Batch 6905/16894 has loss 2.958902597427368
# Time:  07:18:32  Epoch: 1, Batch 7005/16894 has loss 1.4120919704437256
# Time:  07:18:44  Epoch: 1, Batch 7105/16894 has loss 1.941627860069275
# Time:  07:18:57  Epoch: 1, Batch 7205/16894 has loss 1.772935152053833
# Time:  07:19:09  Epoch: 1, Batch 7305/16894 has loss 2.16241192817688
# Time:  07:19:22  Epoch: 1, Batch 7405/16894 has loss 1.8975820541381836
# Time:  07:19:34  Epoch: 1, Batch 7505/16894 has loss 2.0148253440856934
# Time:  07:19:47  Epoch: 1, Batch 7605/16894 has loss 1.852009892463684
# Time:  07:19:59  Epoch: 1, Batch 7705/16894 has loss 2.003556251525879
# Time:  07:20:12  Epoch: 1, Batch 7805/16894 has loss 2.0861501693725586
# Time:  07:20:24  Epoch: 1, Batch 7905/16894 has loss 1.7391374111175537
# Time:  07:20:36  Epoch: 1, Batch 8005/16894 has loss 1.1463861465454102
# Time:  07:20:48  Epoch: 1, Batch 8105/16894 has loss 1.9330402612686157
# Time:  07:21:01  Epoch: 1, Batch 8205/16894 has loss 2.060605525970459
# Time:  07:21:13  Epoch: 1, Batch 8305/16894 has loss 2.8383727073669434
# Time:  07:21:26  Epoch: 1, Batch 8405/16894 has loss 2.0859103202819824
# Time:  07:21:38  Epoch: 1, Batch 8505/16894 has loss 1.5924800634384155
# Time:  07:21:50  Epoch: 1, Batch 8605/16894 has loss 1.9378668069839478
# Time:  07:22:03  Epoch: 1, Batch 8705/16894 has loss 1.8002554178237915
# Time:  07:22:15  Epoch: 1, Batch 8805/16894 has loss 1.952419638633728
# Time:  07:22:27  Epoch: 1, Batch 8905/16894 has loss 1.355749249458313
# Time:  07:22:40  Epoch: 1, Batch 9005/16894 has loss 1.4416955709457397
# Time:  07:22:52  Epoch: 1, Batch 9105/16894 has loss 1.5920251607894897
# Time:  07:23:04  Epoch: 1, Batch 9205/16894 has loss 1.6892614364624023
# Time:  07:23:17  Epoch: 1, Batch 9305/16894 has loss 1.9106826782226562
# Time:  07:23:30  Epoch: 1, Batch 9405/16894 has loss 1.8692970275878906
# Time:  07:23:42  Epoch: 1, Batch 9505/16894 has loss 2.046563148498535
# Time:  07:23:55  Epoch: 1, Batch 9605/16894 has loss 1.8965411186218262
# Time:  07:24:07  Epoch: 1, Batch 9705/16894 has loss 2.486532688140869
# Time:  07:24:19  Epoch: 1, Batch 9805/16894 has loss 1.9918345212936401
# Time:  07:24:32  Epoch: 1, Batch 9905/16894 has loss 1.979073166847229
# Time:  07:24:44  Epoch: 1, Batch 10005/16894 has loss 2.5843143463134766
# Time:  07:24:57  Epoch: 1, Batch 10105/16894 has loss 1.915073275566101
# Time:  07:25:09  Epoch: 1, Batch 10205/16894 has loss 1.2945170402526855
# Time:  07:25:22  Epoch: 1, Batch 10305/16894 has loss 1.536166787147522
# Time:  07:25:34  Epoch: 1, Batch 10405/16894 has loss 1.6052699089050293
# Time:  07:25:46  Epoch: 1, Batch 10505/16894 has loss 2.262474536895752
# Time:  07:25:59  Epoch: 1, Batch 10605/16894 has loss 1.6556249856948853
# Time:  07:26:11  Epoch: 1, Batch 10705/16894 has loss 1.760128378868103
# Time:  07:26:24  Epoch: 1, Batch 10805/16894 has loss 1.4849095344543457
# Time:  07:26:36  Epoch: 1, Batch 10905/16894 has loss 1.4898219108581543
# Time:  07:26:48  Epoch: 1, Batch 11005/16894 has loss 2.3011717796325684
# Time:  07:27:01  Epoch: 1, Batch 11105/16894 has loss 1.9908283948898315
# Time:  07:27:13  Epoch: 1, Batch 11205/16894 has loss 1.5484416484832764
# Time:  07:27:26  Epoch: 1, Batch 11305/16894 has loss 1.5649464130401611
# Time:  07:27:38  Epoch: 1, Batch 11405/16894 has loss 1.9442213773727417
# Time:  07:27:51  Epoch: 1, Batch 11505/16894 has loss 1.8836112022399902
# Time:  07:28:03  Epoch: 1, Batch 11605/16894 has loss 1.852566123008728
# Time:  07:28:15  Epoch: 1, Batch 11705/16894 has loss 1.5142219066619873
# Time:  07:28:28  Epoch: 1, Batch 11805/16894 has loss 1.491221308708191
# Time:  07:28:40  Epoch: 1, Batch 11905/16894 has loss 1.704777479171753
# Time:  07:28:53  Epoch: 1, Batch 12005/16894 has loss 1.8122135400772095
# Time:  07:29:05  Epoch: 1, Batch 12105/16894 has loss 2.2105085849761963
# Time:  07:29:18  Epoch: 1, Batch 12205/16894 has loss 1.9070762395858765
# Time:  07:29:30  Epoch: 1, Batch 12305/16894 has loss 2.1971335411071777
# Time:  07:29:42  Epoch: 1, Batch 12405/16894 has loss 1.422990322113037
# Time:  07:29:55  Epoch: 1, Batch 12505/16894 has loss 1.8989261388778687
# Time:  07:30:07  Epoch: 1, Batch 12605/16894 has loss 2.025010585784912
# Time:  07:30:20  Epoch: 1, Batch 12705/16894 has loss 1.3345730304718018
# Time:  07:30:32  Epoch: 1, Batch 12805/16894 has loss 2.4028687477111816
# Time:  07:30:44  Epoch: 1, Batch 12905/16894 has loss 2.0611073970794678
# Time:  07:30:57  Epoch: 1, Batch 13005/16894 has loss 2.561068534851074
# Time:  07:31:09  Epoch: 1, Batch 13105/16894 has loss 2.247084379196167
# Time:  07:31:22  Epoch: 1, Batch 13205/16894 has loss 1.9270564317703247
# Time:  07:31:34  Epoch: 1, Batch 13305/16894 has loss 1.7392865419387817
# Time:  07:31:47  Epoch: 1, Batch 13405/16894 has loss 1.5295262336730957
# Time:  07:31:59  Epoch: 1, Batch 13505/16894 has loss 1.4146326780319214
# Time:  07:32:11  Epoch: 1, Batch 13605/16894 has loss 1.2604941129684448
# Time:  07:32:24  Epoch: 1, Batch 13705/16894 has loss 1.882765769958496
# Time:  07:32:36  Epoch: 1, Batch 13805/16894 has loss 1.421949028968811
# Time:  07:32:49  Epoch: 1, Batch 13905/16894 has loss 2.733254909515381
# Time:  07:33:01  Epoch: 1, Batch 14005/16894 has loss 1.6216545104980469
# Time:  07:33:14  Epoch: 1, Batch 14105/16894 has loss 2.3843555450439453
# Time:  07:33:26  Epoch: 1, Batch 14205/16894 has loss 1.377991795539856
# Time:  07:33:38  Epoch: 1, Batch 14305/16894 has loss 2.6773815155029297
# Time:  07:33:51  Epoch: 1, Batch 14405/16894 has loss 3.0902600288391113
# Time:  07:34:03  Epoch: 1, Batch 14505/16894 has loss 1.5255303382873535
# Time:  07:34:15  Epoch: 1, Batch 14605/16894 has loss 2.1909713745117188
# Time:  07:34:28  Epoch: 1, Batch 14705/16894 has loss 1.4679588079452515
# Time:  07:34:40  Epoch: 1, Batch 14805/16894 has loss 2.338268995285034
# Time:  07:34:52  Epoch: 1, Batch 14905/16894 has loss 3.0401089191436768
# Time:  07:35:05  Epoch: 1, Batch 15005/16894 has loss 1.9064747095108032
# Time:  07:35:17  Epoch: 1, Batch 15105/16894 has loss 2.822317123413086
# Time:  07:35:30  Epoch: 1, Batch 15205/16894 has loss 1.3605953454971313
# Time:  07:35:42  Epoch: 1, Batch 15305/16894 has loss 1.942312479019165
# Time:  07:35:54  Epoch: 1, Batch 15405/16894 has loss 1.551853895187378
# Time:  07:36:07  Epoch: 1, Batch 15505/16894 has loss 1.7231478691101074
# Time:  07:36:19  Epoch: 1, Batch 15605/16894 has loss 2.065643548965454
# Time:  07:36:31  Epoch: 1, Batch 15705/16894 has loss 2.839125871658325
# Time:  07:36:44  Epoch: 1, Batch 15805/16894 has loss 2.5959091186523438
# Time:  07:36:56  Epoch: 1, Batch 15905/16894 has loss 1.7993159294128418
# Time:  07:37:09  Epoch: 1, Batch 16005/16894 has loss 2.056670665740967
# Time:  07:37:21  Epoch: 1, Batch 16105/16894 has loss 1.2713497877120972
# Time:  07:37:34  Epoch: 1, Batch 16205/16894 has loss 2.586329698562622
# Time:  07:37:46  Epoch: 1, Batch 16305/16894 has loss 1.5331498384475708
# Time:  07:37:58  Epoch: 1, Batch 16405/16894 has loss 1.4533371925354004
# Time:  07:38:11  Epoch: 1, Batch 16505/16894 has loss 2.0434763431549072
# Time:  07:38:23  Epoch: 1, Batch 16605/16894 has loss 1.773339867591858
# Time:  07:38:35  Epoch: 1, Batch 16705/16894 has loss 2.015967607498169
# Time:  07:38:48  Epoch: 1, Batch 16805/16894 has loss 1.7818427085876465
# Validation Accuracy: 0.476800
# Validation Accuracy: 0.484000
# Validation Accuracy: 0.484800
# Validation Accuracy: 0.482600
# Validation Accuracy: 0.486720
# Validation Accuracy: 0.486667
# Validation Accuracy: 0.485714
# Validation Accuracy: 0.483200
# Validation Accuracy: 0.483022
# Validation Accuracy: 0.482720
# Validation Accuracy: 0.482327
# Validation Accuracy: 0.483000
# Validation Accuracy: 0.480985
# Validation Accuracy: 0.480057
# Validation Accuracy: 0.480533
# Validation Accuracy: 0.480250
# Validation Accuracy: 0.481694
# Validation Accuracy: 0.482089
# Validation Accuracy: 0.481895
# Validation Accuracy: 0.481200
# Validation Accuracy: 0.480952
# Validation Accuracy: 0.481418
# Validation Accuracy: 0.481357
# Validation Accuracy: 0.480967
# Validation Accuracy: 0.479936
# Validation Accuracy: 0.479877
# Validation Accuracy: 0.480415
# Validation Accuracy: 0.481343
# Validation Accuracy: 0.481352
# Validation Accuracy: 0.481253
# Validation Accuracy: 0.482452
# Validation Accuracy: 0.481325
# Validation Accuracy: 0.480752
# Validation Accuracy: 0.480894
# Validation Accuracy: 0.481029
# Validation Accuracy: 0.481022
# Validation Accuracy: 0.480822
# Validation Accuracy: 0.480674
# Validation Accuracy: 0.481518
# Validation Accuracy: 0.481680
# Validation Accuracy: 0.482380
# Validation Accuracy: 0.483067
# Validation Accuracy: 0.482847
# Validation Accuracy: 0.483073
# Validation Accuracy: 0.482844
# Validation Accuracy: 0.482870
# Validation Accuracy: 0.482672
# Validation Accuracy: 0.482700
# Validation Accuracy: 0.482792
# Validation Accuracy: 0.482256
# Validation Accuracy: 0.482243
# Validation Accuracy: 0.482308
# Validation Accuracy: 0.482294
# Validation Accuracy: 0.482222
# Validation Accuracy: 0.481920
# Validation Accuracy: 0.481486
# Validation Accuracy: 0.481740
# Validation Accuracy: 0.481738
# Validation Accuracy: 0.481749
# Validation Accuracy: 0.481507
# Validation Accuracy: 0.481587
# Validation Accuracy: 0.481535
# Validation Accuracy: 0.481587
# Validation Accuracy: 0.481938
# Validation Accuracy: 0.482154
# Validation Accuracy: 0.482424
# Validation Accuracy: 0.482448
# Validation Accuracy: 0.482024
# Validation Accuracy: 0.481646
# Validation Accuracy: 0.481909
# Validation Accuracy: 0.481803
# Validation Accuracy: 0.482067
# Validation Accuracy: 0.482170
# Validation Accuracy: 0.481892
# Validation Accuracy: 0.481547
# Validation Accuracy: 0.481379
# Validation Accuracy: 0.481081
# Validation Accuracy: 0.480533
# Validation Accuracy: 0.480223
# Validation Accuracy: 0.480360
# Validation Accuracy: 0.480247
# Validation Accuracy: 0.480088
# Validation Accuracy: 0.480328
# Validation Accuracy: 0.480267
# Validation Accuracy: 0.480442
# Validation Accuracy: 0.480456
# Validation Accuracy: 0.480478
# Validation Accuracy: 0.480464
# Validation Accuracy: 0.480539
# Validation Accuracy: 0.480400
# Validation Accuracy: 0.480264
# Validation Accuracy: 0.480191
# Validation Accuracy: 0.480637
# Validation Accuracy: 0.480706
# Validation Accuracy: 0.480724
# Validation Accuracy: 0.480800
# Validation Accuracy: 0.481056
# Validation Accuracy: 0.480857
# Validation Accuracy: 0.480857
# Validation Accuracy: 0.480792
# Validation Accuracy: 0.480903
# Validation Accuracy: 0.481106
# Validation Accuracy: 0.481150
# Validation Accuracy: 0.480954
# Validation Accuracy: 0.480899
# Validation Accuracy: 0.480649
# Validation Accuracy: 0.480852
# Validation Accuracy: 0.480741
# Validation Accuracy: 0.480653
# Validation Accuracy: 0.480487
# Validation Accuracy: 0.480144
# Validation Accuracy: 0.480314
# Validation Accuracy: 0.480368
# Validation Accuracy: 0.480582
# Validation Accuracy: 0.480550
# Validation Accuracy: 0.480490
# Validation Accuracy: 0.480513
# Validation Accuracy: 0.480664
# Validation Accuracy: 0.480524
# Validation Accuracy: 0.480340
# Validation Accuracy: 0.480496
# Validation Accuracy: 0.480459
# Validation Accuracy: 0.480397
# Validation Accuracy: 0.480374
# Validation Accuracy: 0.480051
# Validation Accuracy: 0.480171
# Validation Accuracy: 0.479987
# Validation Accuracy: 0.479744
# Validation Accuracy: 0.479808
# Validation Accuracy: 0.479692
# Validation Accuracy: 0.479646
# Validation Accuracy: 0.479612
# Validation Accuracy: 0.479561
# Validation Accuracy: 0.479409
# Validation Accuracy: 0.479159
# Validation Accuracy: 0.479259
# Validation Accuracy: 0.479311
# Validation Accuracy: 0.479374
# Validation Accuracy: 0.479332
# Validation Accuracy: 0.479514
# Validation Accuracy: 0.479654
# Validation Accuracy: 0.479606
# Validation Accuracy: 0.479502
# Validation Accuracy: 0.479317
# Validation Accuracy: 0.479514
# Validation Accuracy: 0.479375
# Validation Accuracy: 0.479265
# Validation Accuracy: 0.479141
# Validation Accuracy: 0.479200
# Validation Accuracy: 0.479163
# Validation Accuracy: 0.479041
# Validation Accuracy: 0.478800
# Validation Accuracy: 0.478703
# Validation Accuracy: 0.478608
# Validation Accuracy: 0.478498
# Validation Accuracy: 0.478533
# Validation Accuracy: 0.478441
# Validation Accuracy: 0.478461
# Validation Accuracy: 0.478501
# Validation Accuracy: 0.478545
# Validation Accuracy: 0.478589
# Validation Accuracy: 0.478681
# number of accurate answers is  97486.0  out of the total number of validation questions  214354.0
# accuracy % is  45.478974033607955
# Epoch: 1 has val accuracy 0.45478974033607955
# saving checkpoint at  /content/drive/MyDrive/VQA/chk_coattention/checkpoint_2.pth.tar
# Time:  07:54:54  Epoch: 2, Batch 11/16894 has loss 1.2521049976348877
# Time:  07:55:06  Epoch: 2, Batch 111/16894 has loss 1.8749691247940063
# Time:  07:55:19  Epoch: 2, Batch 211/16894 has loss 1.959015965461731
# Time:  07:55:31  Epoch: 2, Batch 311/16894 has loss 1.6313687562942505
# Time:  07:55:43  Epoch: 2, Batch 411/16894 has loss 1.7455984354019165
# Time:  07:55:56  Epoch: 2, Batch 511/16894 has loss 2.1918861865997314
# Time:  07:56:08  Epoch: 2, Batch 611/16894 has loss 2.0802135467529297
# Time:  07:56:21  Epoch: 2, Batch 711/16894 has loss 2.245359420776367
# Time:  07:56:33  Epoch: 2, Batch 811/16894 has loss 1.4057250022888184
# Time:  07:56:45  Epoch: 2, Batch 911/16894 has loss 1.7812532186508179
# Time:  07:56:58  Epoch: 2, Batch 1011/16894 has loss 2.109591007232666
# Time:  07:57:10  Epoch: 2, Batch 1111/16894 has loss 1.441308617591858
# Time:  07:57:23  Epoch: 2, Batch 1211/16894 has loss 2.424697160720825
# Time:  07:57:35  Epoch: 2, Batch 1311/16894 has loss 2.130563974380493
# Time:  07:57:48  Epoch: 2, Batch 1411/16894 has loss 2.256258964538574
# Time:  07:58:00  Epoch: 2, Batch 1511/16894 has loss 1.764876127243042
# Time:  07:58:12  Epoch: 2, Batch 1611/16894 has loss 2.8415021896362305
# Time:  07:58:25  Epoch: 2, Batch 1711/16894 has loss 1.7865052223205566
# Time:  07:58:37  Epoch: 2, Batch 1811/16894 has loss 2.2549684047698975
# Time:  07:58:49  Epoch: 2, Batch 1911/16894 has loss 2.306107521057129
# Time:  07:59:02  Epoch: 2, Batch 2011/16894 has loss 1.4334007501602173
# Time:  07:59:14  Epoch: 2, Batch 2111/16894 has loss 1.7561160326004028
# Time:  07:59:27  Epoch: 2, Batch 2211/16894 has loss 1.6648319959640503
# Time:  07:59:39  Epoch: 2, Batch 2311/16894 has loss 1.7644973993301392
# Time:  07:59:52  Epoch: 2, Batch 2411/16894 has loss 1.683487892150879
# Time:  08:00:04  Epoch: 2, Batch 2511/16894 has loss 2.0938801765441895
# Time:  08:00:17  Epoch: 2, Batch 2611/16894 has loss 2.014028549194336
# Time:  08:00:29  Epoch: 2, Batch 2711/16894 has loss 1.4526371955871582
# Time:  08:00:41  Epoch: 2, Batch 2811/16894 has loss 1.3494672775268555
# Time:  08:00:54  Epoch: 2, Batch 2911/16894 has loss 2.2234771251678467
# Time:  08:01:06  Epoch: 2, Batch 3011/16894 has loss 3.005850315093994
# Time:  08:01:19  Epoch: 2, Batch 3111/16894 has loss 1.9023076295852661
# Time:  08:01:31  Epoch: 2, Batch 3211/16894 has loss 1.6751415729522705
# Time:  08:01:43  Epoch: 2, Batch 3311/16894 has loss 2.4165079593658447
# Time:  08:01:56  Epoch: 2, Batch 3411/16894 has loss 2.17138671875
# Time:  08:02:08  Epoch: 2, Batch 3511/16894 has loss 1.717843770980835
# Time:  08:02:21  Epoch: 2, Batch 3611/16894 has loss 1.7971627712249756
# Time:  08:02:33  Epoch: 2, Batch 3711/16894 has loss 1.6758673191070557
# Time:  08:02:46  Epoch: 2, Batch 3811/16894 has loss 1.9711564779281616
# Time:  08:02:58  Epoch: 2, Batch 3911/16894 has loss 2.218517541885376
# Time:  08:03:11  Epoch: 2, Batch 4011/16894 has loss 1.6365917921066284
# Time:  08:03:23  Epoch: 2, Batch 4111/16894 has loss 2.3900842666625977
# Time:  08:03:36  Epoch: 2, Batch 4211/16894 has loss 1.5443702936172485
# Time:  08:03:48  Epoch: 2, Batch 4311/16894 has loss 2.0277819633483887
# Time:  08:04:00  Epoch: 2, Batch 4411/16894 has loss 1.9124521017074585
# Time:  08:04:13  Epoch: 2, Batch 4511/16894 has loss 2.1066465377807617
# Time:  08:04:25  Epoch: 2, Batch 4611/16894 has loss 1.8378806114196777
# Time:  08:04:37  Epoch: 2, Batch 4711/16894 has loss 2.151111364364624
# Time:  08:04:50  Epoch: 2, Batch 4811/16894 has loss 1.9907935857772827
# Time:  08:05:03  Epoch: 2, Batch 4911/16894 has loss 1.6750117540359497
# Time:  08:05:15  Epoch: 2, Batch 5011/16894 has loss 1.8278602361679077
# Time:  08:05:27  Epoch: 2, Batch 5111/16894 has loss 1.9547500610351562
# Time:  08:05:40  Epoch: 2, Batch 5211/16894 has loss 2.650632858276367
# Time:  08:05:52  Epoch: 2, Batch 5311/16894 has loss 1.3143057823181152
# Time:  08:06:05  Epoch: 2, Batch 5411/16894 has loss 1.8503837585449219
# Time:  08:06:17  Epoch: 2, Batch 5511/16894 has loss 1.1946954727172852
# Time:  08:06:30  Epoch: 2, Batch 5611/16894 has loss 1.581021785736084
# Time:  08:06:42  Epoch: 2, Batch 5711/16894 has loss 1.7078492641448975
# Time:  08:06:54  Epoch: 2, Batch 5811/16894 has loss 1.8490948677062988
# Time:  08:07:07  Epoch: 2, Batch 5911/16894 has loss 2.2593393325805664
# Time:  08:07:19  Epoch: 2, Batch 6011/16894 has loss 1.6671087741851807
# Time:  08:07:32  Epoch: 2, Batch 6111/16894 has loss 1.916499137878418
# Time:  08:07:44  Epoch: 2, Batch 6211/16894 has loss 1.6324995756149292
# Time:  08:07:57  Epoch: 2, Batch 6311/16894 has loss 1.5458731651306152
# Time:  08:08:09  Epoch: 2, Batch 6411/16894 has loss 1.5842055082321167
# Time:  08:08:21  Epoch: 2, Batch 6511/16894 has loss 2.135610580444336
# Time:  08:08:34  Epoch: 2, Batch 6611/16894 has loss 1.499728798866272
# Time:  08:08:46  Epoch: 2, Batch 6711/16894 has loss 1.8468542098999023
# Time:  08:08:59  Epoch: 2, Batch 6811/16894 has loss 1.5560139417648315
# Time:  08:09:11  Epoch: 2, Batch 6911/16894 has loss 2.096604347229004
# Time:  08:09:24  Epoch: 2, Batch 7011/16894 has loss 2.015613317489624
# Time:  08:09:36  Epoch: 2, Batch 7111/16894 has loss 2.1776316165924072
# Time:  08:09:48  Epoch: 2, Batch 7211/16894 has loss 2.0145957469940186
# Time:  08:10:01  Epoch: 2, Batch 7311/16894 has loss 2.209491491317749
# Time:  08:10:13  Epoch: 2, Batch 7411/16894 has loss 1.7315435409545898
# Time:  08:10:26  Epoch: 2, Batch 7511/16894 has loss 2.0770442485809326
# Time:  08:10:38  Epoch: 2, Batch 7611/16894 has loss 1.3235996961593628
# Time:  08:10:51  Epoch: 2, Batch 7711/16894 has loss 1.5562493801116943
# Time:  08:11:04  Epoch: 2, Batch 7811/16894 has loss 1.8412070274353027
# Time:  08:11:16  Epoch: 2, Batch 7911/16894 has loss 1.9313392639160156
# Time:  08:11:28  Epoch: 2, Batch 8011/16894 has loss 2.6764917373657227
# Time:  08:11:41  Epoch: 2, Batch 8111/16894 has loss 1.429783582687378
# Time:  08:11:53  Epoch: 2, Batch 8211/16894 has loss 1.961690068244934
# Time:  08:12:06  Epoch: 2, Batch 8311/16894 has loss 2.7903096675872803
# Time:  08:12:18  Epoch: 2, Batch 8411/16894 has loss 2.1714224815368652
# Time:  08:12:30  Epoch: 2, Batch 8511/16894 has loss 1.9318022727966309
# Time:  08:12:43  Epoch: 2, Batch 8611/16894 has loss 2.4114084243774414
# Time:  08:12:55  Epoch: 2, Batch 8711/16894 has loss 2.2984976768493652
# Time:  08:13:08  Epoch: 2, Batch 8811/16894 has loss 1.8604114055633545
# Time:  08:13:21  Epoch: 2, Batch 8911/16894 has loss 2.3056836128234863
# Time:  08:13:35  Epoch: 2, Batch 9011/16894 has loss 2.1094906330108643
# Time:  08:13:48  Epoch: 2, Batch 9111/16894 has loss 2.701326847076416
# Time:  08:14:01  Epoch: 2, Batch 9211/16894 has loss 1.0909380912780762
# Time:  08:14:14  Epoch: 2, Batch 9311/16894 has loss 2.043705463409424
# Time:  08:14:26  Epoch: 2, Batch 9411/16894 has loss 2.0741922855377197
# Time:  08:14:38  Epoch: 2, Batch 9511/16894 has loss 1.6099237203598022
# Time:  08:14:51  Epoch: 2, Batch 9611/16894 has loss 1.765066385269165
# Time:  08:15:03  Epoch: 2, Batch 9711/16894 has loss 2.1302649974823
# Time:  08:15:16  Epoch: 2, Batch 9811/16894 has loss 1.871424913406372
# Time:  08:15:28  Epoch: 2, Batch 9911/16894 has loss 2.1608519554138184
# Time:  08:15:41  Epoch: 2, Batch 10011/16894 has loss 2.3381154537200928
# Time:  08:15:53  Epoch: 2, Batch 10111/16894 has loss 2.221356153488159
# Time:  08:16:06  Epoch: 2, Batch 10211/16894 has loss 1.6654623746871948
# Time:  08:16:18  Epoch: 2, Batch 10311/16894 has loss 2.037257194519043
# Time:  08:16:30  Epoch: 2, Batch 10411/16894 has loss 2.439979314804077
# Time:  08:16:43  Epoch: 2, Batch 10511/16894 has loss 2.6759424209594727
# Time:  08:16:55  Epoch: 2, Batch 10611/16894 has loss 1.6184173822402954
# Time:  08:17:08  Epoch: 2, Batch 10711/16894 has loss 2.6589407920837402
# Time:  08:17:20  Epoch: 2, Batch 10811/16894 has loss 1.183591365814209
# Time:  08:17:33  Epoch: 2, Batch 10911/16894 has loss 1.941259741783142
# Time:  08:17:45  Epoch: 2, Batch 11011/16894 has loss 1.9090657234191895
# Time:  08:17:58  Epoch: 2, Batch 11111/16894 has loss 1.09652841091156
# Time:  08:18:10  Epoch: 2, Batch 11211/16894 has loss 1.5712864398956299
# Time:  08:18:23  Epoch: 2, Batch 11311/16894 has loss 1.475965142250061
# Time:  08:18:35  Epoch: 2, Batch 11411/16894 has loss 1.7503066062927246
# Time:  08:18:47  Epoch: 2, Batch 11511/16894 has loss 1.3937028646469116
# Time:  08:19:00  Epoch: 2, Batch 11611/16894 has loss 1.5084608793258667
# Time:  08:19:12  Epoch: 2, Batch 11711/16894 has loss 2.005478620529175
# Time:  08:19:25  Epoch: 2, Batch 11811/16894 has loss 1.7344610691070557
# Time:  08:19:37  Epoch: 2, Batch 11911/16894 has loss 1.4039143323898315
# Time:  08:19:50  Epoch: 2, Batch 12011/16894 has loss 1.9409093856811523
# Time:  08:20:02  Epoch: 2, Batch 12111/16894 has loss 1.8545182943344116
# Time:  08:20:15  Epoch: 2, Batch 12211/16894 has loss 1.1540614366531372
# Time:  08:20:27  Epoch: 2, Batch 12311/16894 has loss 2.4098522663116455
# Time:  08:20:40  Epoch: 2, Batch 12411/16894 has loss 2.1491284370422363
# Time:  08:20:52  Epoch: 2, Batch 12511/16894 has loss 2.582127094268799
# Time:  08:21:05  Epoch: 2, Batch 12611/16894 has loss 2.427053213119507
# Time:  08:21:17  Epoch: 2, Batch 12711/16894 has loss 2.376873254776001
# Time:  08:21:30  Epoch: 2, Batch 12811/16894 has loss 1.6049439907073975
# Time:  08:21:42  Epoch: 2, Batch 12911/16894 has loss 1.3054219484329224
# Time:  08:21:55  Epoch: 2, Batch 13011/16894 has loss 1.1041789054870605
# Time:  08:22:07  Epoch: 2, Batch 13111/16894 has loss 1.6719590425491333
# Time:  08:22:20  Epoch: 2, Batch 13211/16894 has loss 1.8227226734161377
# Time:  08:22:32  Epoch: 2, Batch 13311/16894 has loss 1.3609809875488281
# Time:  08:22:45  Epoch: 2, Batch 13411/16894 has loss 2.03605580329895
# Time:  08:22:57  Epoch: 2, Batch 13511/16894 has loss 1.6685296297073364
# Time:  08:23:10  Epoch: 2, Batch 13611/16894 has loss 1.9154787063598633
# Time:  08:23:23  Epoch: 2, Batch 13711/16894 has loss 1.8522772789001465
# Time:  08:23:35  Epoch: 2, Batch 13811/16894 has loss 1.9570965766906738
# Time:  08:23:47  Epoch: 2, Batch 13911/16894 has loss 2.3600308895111084
# Time:  08:24:00  Epoch: 2, Batch 14011/16894 has loss 1.979951024055481
# Time:  08:24:12  Epoch: 2, Batch 14111/16894 has loss 1.6548162698745728
# Time:  08:24:25  Epoch: 2, Batch 14211/16894 has loss 2.3998725414276123
# Time:  08:24:37  Epoch: 2, Batch 14311/16894 has loss 1.7393784523010254
# Time:  08:24:50  Epoch: 2, Batch 14411/16894 has loss 1.521512746810913
# Time:  08:25:02  Epoch: 2, Batch 14511/16894 has loss 1.3933566808700562
# Time:  08:25:15  Epoch: 2, Batch 14611/16894 has loss 2.1588857173919678
# Time:  08:25:27  Epoch: 2, Batch 14711/16894 has loss 1.654758334159851
# Time:  08:25:40  Epoch: 2, Batch 14811/16894 has loss 2.209182024002075
# Time:  08:25:53  Epoch: 2, Batch 14911/16894 has loss 1.8059265613555908
# Time:  08:26:05  Epoch: 2, Batch 15011/16894 has loss 1.8410804271697998
# Time:  08:26:18  Epoch: 2, Batch 15111/16894 has loss 2.0477004051208496
# Time:  08:26:30  Epoch: 2, Batch 15211/16894 has loss 2.100804328918457
# Time:  08:26:43  Epoch: 2, Batch 15311/16894 has loss 1.4042680263519287
# Time:  08:26:56  Epoch: 2, Batch 15411/16894 has loss 1.8830041885375977
# Time:  08:27:08  Epoch: 2, Batch 15511/16894 has loss 2.3879427909851074
# Time:  08:27:21  Epoch: 2, Batch 15611/16894 has loss 2.08536958694458
# Time:  08:27:33  Epoch: 2, Batch 15711/16894 has loss 1.491609811782837
# Time:  08:27:45  Epoch: 2, Batch 15811/16894 has loss 2.3034584522247314
# Time:  08:27:58  Epoch: 2, Batch 15911/16894 has loss 2.469491481781006
# Time:  08:28:11  Epoch: 2, Batch 16011/16894 has loss 2.213731050491333
# Time:  08:28:23  Epoch: 2, Batch 16111/16894 has loss 1.6692203283309937
# Time:  08:28:36  Epoch: 2, Batch 16211/16894 has loss 2.071668863296509
# Time:  08:28:48  Epoch: 2, Batch 16311/16894 has loss 1.3757706880569458
# Time:  08:29:00  Epoch: 2, Batch 16411/16894 has loss 2.182133436203003
# Time:  08:29:13  Epoch: 2, Batch 16511/16894 has loss 1.8000328540802002
# Time:  08:29:25  Epoch: 2, Batch 16611/16894 has loss 2.6889963150024414
# Time:  08:29:38  Epoch: 2, Batch 16711/16894 has loss 1.0724927186965942
# Time:  08:29:51  Epoch: 2, Batch 16811/16894 has loss 1.3052008152008057
# Validation Accuracy: 0.476000
# Validation Accuracy: 0.482400
# Validation Accuracy: 0.483200
# ...
# Time:  14:59:31  Epoch: 10, Batch 4259/16894 has loss 1.5975755453109741
# Time:  14:59:43  Epoch: 10, Batch 4359/16894 has loss 2.552365779876709
# Time:  14:59:56  Epoch: 10, Batch 4459/16894 has loss 1.5611249208450317
# Time:  15:00:08  Epoch: 10, Batch 4559/16894 has loss 1.5279849767684937
# Time:  15:00:21  Epoch: 10, Batch 4659/16894 has loss 1.7985950708389282
# Time:  15:00:33  Epoch: 10, Batch 4759/16894 has loss 1.4734212160110474
# Time:  15:00:46  Epoch: 10, Batch 4859/16894 has loss 1.6029994487762451
# Time:  15:00:58  Epoch: 10, Batch 4959/16894 has loss 2.016383409500122
# Time:  15:01:11  Epoch: 10, Batch 5059/16894 has loss 1.4337495565414429
# Time:  15:01:24  Epoch: 10, Batch 5159/16894 has loss 1.8199406862258911
# Time:  15:01:36  Epoch: 10, Batch 5259/16894 has loss 1.7528409957885742
# Time:  15:01:49  Epoch: 10, Batch 5359/16894 has loss 1.2286661863327026
# Time:  15:02:01  Epoch: 10, Batch 5459/16894 has loss 1.9958282709121704
# Time:  15:02:14  Epoch: 10, Batch 5559/16894 has loss 1.5778840780258179
# Time:  15:02:26  Epoch: 10, Batch 5659/16894 has loss 1.8982540369033813
# Time:  15:02:39  Epoch: 10, Batch 5759/16894 has loss 1.7450848817825317
# Time:  15:02:51  Epoch: 10, Batch 5859/16894 has loss 1.5032336711883545
# Time:  15:03:04  Epoch: 10, Batch 5959/16894 has loss 2.056525468826294
# Time:  15:03:16  Epoch: 10, Batch 6059/16894 has loss 2.039700508117676
# Time:  15:03:29  Epoch: 10, Batch 6159/16894 has loss 1.7320274114608765
# Time:  15:03:41  Epoch: 10, Batch 6259/16894 has loss 1.9792799949645996
# Time:  15:03:54  Epoch: 10, Batch 6359/16894 has loss 1.468224048614502
# Time:  15:04:07  Epoch: 10, Batch 6459/16894 has loss 1.4373154640197754
# Time:  15:04:19  Epoch: 10, Batch 6559/16894 has loss 1.601171612739563
# Time:  15:04:32  Epoch: 10, Batch 6659/16894 has loss 1.7359001636505127
# Time:  15:04:45  Epoch: 10, Batch 6759/16894 has loss 1.4756169319152832
# Time:  15:04:57  Epoch: 10, Batch 6859/16894 has loss 1.5250048637390137
# Time:  15:05:10  Epoch: 10, Batch 6959/16894 has loss 1.8247143030166626
# Time:  15:05:22  Epoch: 10, Batch 7059/16894 has loss 1.6752731800079346
# Time:  15:05:35  Epoch: 10, Batch 7159/16894 has loss 1.5331748723983765
# Time:  15:05:48  Epoch: 10, Batch 7259/16894 has loss 1.5020480155944824
# Time:  15:06:00  Epoch: 10, Batch 7359/16894 has loss 1.472716212272644
# Time:  15:06:13  Epoch: 10, Batch 7459/16894 has loss 1.7530347108840942
# Time:  15:06:26  Epoch: 10, Batch 7559/16894 has loss 2.0640642642974854
# Time:  15:06:38  Epoch: 10, Batch 7659/16894 has loss 1.7578256130218506
# Time:  15:06:51  Epoch: 10, Batch 7759/16894 has loss 1.5571379661560059
# Time:  15:07:04  Epoch: 10, Batch 7859/16894 has loss 1.024174451828003
# Time:  15:07:16  Epoch: 10, Batch 7959/16894 has loss 1.047836184501648
# Time:  15:07:29  Epoch: 10, Batch 8059/16894 has loss 1.486723780632019
# Time:  15:07:41  Epoch: 10, Batch 8159/16894 has loss 2.3944568634033203
# Time:  15:07:54  Epoch: 10, Batch 8259/16894 has loss 1.7731508016586304
# Time:  15:08:07  Epoch: 10, Batch 8359/16894 has loss 1.550672173500061
# Time:  15:08:19  Epoch: 10, Batch 8459/16894 has loss 2.2976551055908203
# Time:  15:08:32  Epoch: 10, Batch 8559/16894 has loss 1.081068515777588
# Time:  15:08:44  Epoch: 10, Batch 8659/16894 has loss 1.933933138847351
# Time:  15:08:57  Epoch: 10, Batch 8759/16894 has loss 2.107901096343994
# Time:  15:09:10  Epoch: 10, Batch 8859/16894 has loss 1.090253472328186
# Time:  15:09:22  Epoch: 10, Batch 8959/16894 has loss 2.430356502532959
# Time:  15:09:35  Epoch: 10, Batch 9059/16894 has loss 1.7252484560012817
# Time:  15:09:48  Epoch: 10, Batch 9159/16894 has loss 1.7532647848129272
# Time:  15:10:00  Epoch: 10, Batch 9259/16894 has loss 2.217008113861084
# Time:  15:10:13  Epoch: 10, Batch 9359/16894 has loss 1.4419926404953003
# Time:  15:10:25  Epoch: 10, Batch 9459/16894 has loss 1.873801827430725
# Time:  15:10:38  Epoch: 10, Batch 9559/16894 has loss 1.5267035961151123
# Time:  15:10:51  Epoch: 10, Batch 9659/16894 has loss 1.4640387296676636
# Time:  15:11:03  Epoch: 10, Batch 9759/16894 has loss 1.627088189125061
# Time:  15:11:16  Epoch: 10, Batch 9859/16894 has loss 1.3764108419418335
# Time:  15:11:28  Epoch: 10, Batch 9959/16894 has loss 2.2193922996520996
# Time:  15:11:41  Epoch: 10, Batch 10059/16894 has loss 1.215881109237671
# Time:  15:11:53  Epoch: 10, Batch 10159/16894 has loss 1.8372193574905396
# Time:  15:12:06  Epoch: 10, Batch 10259/16894 has loss 1.5517200231552124
# Time:  15:12:19  Epoch: 10, Batch 10359/16894 has loss 1.4260183572769165
# Time:  15:12:31  Epoch: 10, Batch 10459/16894 has loss 1.9009095430374146
# Time:  15:12:44  Epoch: 10, Batch 10559/16894 has loss 1.3980821371078491
# Time:  15:12:56  Epoch: 10, Batch 10659/16894 has loss 1.8936047554016113
# Time:  15:13:09  Epoch: 10, Batch 10759/16894 has loss 1.5296664237976074
# Time:  15:13:21  Epoch: 10, Batch 10859/16894 has loss 2.2666661739349365
# Time:  15:13:34  Epoch: 10, Batch 10959/16894 has loss 1.4837456941604614
# Time:  15:13:47  Epoch: 10, Batch 11059/16894 has loss 1.696540117263794
# Time:  15:13:59  Epoch: 10, Batch 11159/16894 has loss 1.854941725730896
# Time:  15:14:12  Epoch: 10, Batch 11259/16894 has loss 2.0137033462524414
# Time:  15:14:24  Epoch: 10, Batch 11359/16894 has loss 1.5566372871398926
# Time:  15:14:37  Epoch: 10, Batch 11459/16894 has loss 1.7480747699737549
# Time:  15:14:49  Epoch: 10, Batch 11559/16894 has loss 1.7328869104385376
# Time:  15:15:02  Epoch: 10, Batch 11659/16894 has loss 1.6374506950378418
# Time:  15:15:14  Epoch: 10, Batch 11759/16894 has loss 2.110893964767456
# Time:  15:15:27  Epoch: 10, Batch 11859/16894 has loss 1.1072394847869873
# Time:  15:15:40  Epoch: 10, Batch 11959/16894 has loss 1.6108993291854858
# Time:  15:15:52  Epoch: 10, Batch 12059/16894 has loss 1.0816528797149658
# Time:  15:16:05  Epoch: 10, Batch 12159/16894 has loss 1.4786105155944824
# Time:  15:16:17  Epoch: 10, Batch 12259/16894 has loss 1.635331153869629
# Time:  15:16:30  Epoch: 10, Batch 12359/16894 has loss 1.6393235921859741
# Time:  15:16:43  Epoch: 10, Batch 12459/16894 has loss 1.1178312301635742
# Time:  15:16:55  Epoch: 10, Batch 12559/16894 has loss 1.1164908409118652
# Time:  15:17:08  Epoch: 10, Batch 12659/16894 has loss 1.1623451709747314
# Time:  15:17:20  Epoch: 10, Batch 12759/16894 has loss 1.7353253364562988
# Time:  15:17:33  Epoch: 10, Batch 12859/16894 has loss 1.8744044303894043
# Time:  15:17:46  Epoch: 10, Batch 12959/16894 has loss 1.901739239692688
# Time:  15:17:58  Epoch: 10, Batch 13059/16894 has loss 2.1648151874542236
# Time:  15:18:11  Epoch: 10, Batch 13159/16894 has loss 1.8240066766738892
# Time:  15:18:24  Epoch: 10, Batch 13259/16894 has loss 1.8089274168014526
# Time:  15:18:36  Epoch: 10, Batch 13359/16894 has loss 1.7826138734817505
# Time:  15:18:49  Epoch: 10, Batch 13459/16894 has loss 1.145373821258545
# Time:  15:19:02  Epoch: 10, Batch 13559/16894 has loss 2.174456834793091
# Time:  15:19:14  Epoch: 10, Batch 13659/16894 has loss 2.288902521133423
# Time:  15:19:27  Epoch: 10, Batch 13759/16894 has loss 1.266027808189392
# Time:  15:19:39  Epoch: 10, Batch 13859/16894 has loss 1.812088966369629
# Time:  15:19:52  Epoch: 10, Batch 13959/16894 has loss 1.4089174270629883
# Time:  15:20:04  Epoch: 10, Batch 14059/16894 has loss 1.6903581619262695
# Time:  15:20:17  Epoch: 10, Batch 14159/16894 has loss 1.9005486965179443
# Time:  15:20:30  Epoch: 10, Batch 14259/16894 has loss 2.2694101333618164
# Time:  15:20:43  Epoch: 10, Batch 14359/16894 has loss 1.3974112272262573
# Time:  15:20:55  Epoch: 10, Batch 14459/16894 has loss 1.3461517095565796
# Time:  15:21:08  Epoch: 10, Batch 14559/16894 has loss 1.6282368898391724
# Time:  15:21:20  Epoch: 10, Batch 14659/16894 has loss 1.886916160583496
# Time:  15:21:33  Epoch: 10, Batch 14759/16894 has loss 1.709993839263916
# Time:  15:21:45  Epoch: 10, Batch 14859/16894 has loss 1.5914708375930786
# Time:  15:21:58  Epoch: 10, Batch 14959/16894 has loss 1.6896193027496338
# Time:  15:22:11  Epoch: 10, Batch 15059/16894 has loss 2.561291217803955
# Time:  15:22:23  Epoch: 10, Batch 15159/16894 has loss 1.4611343145370483
# Time:  15:22:36  Epoch: 10, Batch 15259/16894 has loss 1.9300410747528076
# Time:  15:22:48  Epoch: 10, Batch 15359/16894 has loss 1.5342997312545776
# Time:  15:23:01  Epoch: 10, Batch 15459/16894 has loss 2.526707410812378
# Time:  15:23:14  Epoch: 10, Batch 15559/16894 has loss 1.4286901950836182
# Time:  15:23:26  Epoch: 10, Batch 15659/16894 has loss 1.5208253860473633
# Time:  15:23:39  Epoch: 10, Batch 15759/16894 has loss 1.3027458190917969
# Time:  15:23:52  Epoch: 10, Batch 15859/16894 has loss 1.3120434284210205
# Time:  15:24:04  Epoch: 10, Batch 15959/16894 has loss 1.3979607820510864
# Time:  15:24:17  Epoch: 10, Batch 16059/16894 has loss 2.0234267711639404
# Time:  15:24:30  Epoch: 10, Batch 16159/16894 has loss 1.4209060668945312
# Time:  15:24:43  Epoch: 10, Batch 16259/16894 has loss 1.3583568334579468
# Time:  15:24:56  Epoch: 10, Batch 16359/16894 has loss 1.8025012016296387
# Time:  15:25:08  Epoch: 10, Batch 16459/16894 has loss 1.6080855131149292
# Time:  15:25:21  Epoch: 10, Batch 16559/16894 has loss 1.1041600704193115
# Time:  15:25:34  Epoch: 10, Batch 16659/16894 has loss 1.5198248624801636
# Time:  15:25:46  Epoch: 10, Batch 16759/16894 has loss 1.0223259925842285
# Time:  15:25:59  Epoch: 10, Batch 16859/16894 has loss 1.0200178623199463
# Validation Accuracy: 0.476800
# Validation Accuracy: 0.492400
# Validation Accuracy: 0.493067
# Validation Accuracy: 0.494600
# Validation Accuracy: 0.499680
# Validation Accuracy: 0.498133
# Validation Accuracy: 0.496571
# Validation Accuracy: 0.495400
# Validation Accuracy: 0.495289
# Validation Accuracy: 0.497040
# Validation Accuracy: 0.497164
# Validation Accuracy: 0.497400
# Validation Accuracy: 0.496554
# Validation Accuracy: 0.495886
# Validation Accuracy: 0.495840
# Validation Accuracy: 0.494850
# Validation Accuracy: 0.495765
# Validation Accuracy: 0.497111
# Validation Accuracy: 0.495874
# Validation Accuracy: 0.495120
# Validation Accuracy: 0.495543
# Validation Accuracy: 0.496909
# Validation Accuracy: 0.496313
# Validation Accuracy: 0.495900
# Validation Accuracy: 0.494848
# Validation Accuracy: 0.494738
# Validation Accuracy: 0.495141
# Validation Accuracy: 0.495971
# Validation Accuracy: 0.495779
# Validation Accuracy: 0.495920
# Validation Accuracy: 0.497265
# Validation Accuracy: 0.496800
# Validation Accuracy: 0.496606
# Validation Accuracy: 0.497082
# Validation Accuracy: 0.496503
# Validation Accuracy: 0.496689
# Validation Accuracy: 0.496389
# Validation Accuracy: 0.496253
# Validation Accuracy: 0.496903
# Validation Accuracy: 0.496560
# Validation Accuracy: 0.497034
# Validation Accuracy: 0.497505
# Validation Accuracy: 0.497414
# Validation Accuracy: 0.497545
# Validation Accuracy: 0.497244
# Validation Accuracy: 0.497078
# Validation Accuracy: 0.496664
# Validation Accuracy: 0.496467
# Validation Accuracy: 0.496408
# Validation Accuracy: 0.495712
# Validation Accuracy: 0.495671
# Validation Accuracy: 0.495862
# Validation Accuracy: 0.495713
# Validation Accuracy: 0.495896
# Validation Accuracy: 0.495607
# Validation Accuracy: 0.495400
# Validation Accuracy: 0.495565
# Validation Accuracy: 0.495793
# Validation Accuracy: 0.495742
# Validation Accuracy: 0.495653
# Validation Accuracy: 0.495515
# Validation Accuracy: 0.495355
# Validation Accuracy: 0.495327
# Validation Accuracy: 0.495725
# Validation Accuracy: 0.495877
# Validation Accuracy: 0.496158
# Validation Accuracy: 0.496107
# Validation Accuracy: 0.495647
# Validation Accuracy: 0.495409
# Validation Accuracy: 0.495749
# Validation Accuracy: 0.495459
# Validation Accuracy: 0.495878
# Validation Accuracy: 0.495989
# Validation Accuracy: 0.495762
# Validation Accuracy: 0.495392
# Validation Accuracy: 0.495211
# Validation Accuracy: 0.494878
# Validation Accuracy: 0.494246
# Validation Accuracy: 0.494005
# Validation Accuracy: 0.494140
# Validation Accuracy: 0.493965
# Validation Accuracy: 0.493893
# Validation Accuracy: 0.494072
# Validation Accuracy: 0.493886
# Validation Accuracy: 0.494014
# Validation Accuracy: 0.494037
# Validation Accuracy: 0.494161
# Validation Accuracy: 0.494300
# Validation Accuracy: 0.494481
# Validation Accuracy: 0.494329
# Validation Accuracy: 0.494251
# Validation Accuracy: 0.494200
# Validation Accuracy: 0.494606
# Validation Accuracy: 0.494800
# Validation Accuracy: 0.494914
# Validation Accuracy: 0.495050
# Validation Accuracy: 0.495406
# Validation Accuracy: 0.495102
# Validation Accuracy: 0.495160
# Validation Accuracy: 0.495096
# Validation Accuracy: 0.495200
# Validation Accuracy: 0.495255
# Validation Accuracy: 0.495293
# Validation Accuracy: 0.495123
# Validation Accuracy: 0.495093
# Validation Accuracy: 0.494913
# Validation Accuracy: 0.495185
# Validation Accuracy: 0.495030
# Validation Accuracy: 0.495112
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# <ipython-input-72-1030b997a716> in <module>
#      42                                                 num_epochs=args.num_epochs,
#      43                                                 num_data_loader_workers=args.num_data_loader_workers)
# ---> 44     experiment_runner.train()
#      45
#
# <ipython-input-59-d4dcd5517729> in train(self)
#     180             #print('will be saving checkpoint at ', self.chk_dir + 'checkpoint_' + str(epoch + 1) + '.pth.tar')
#     181             if (epoch + 1) % self._save_freq == 0 or epoch == self._num_epochs - 1:
# --> 182                 val_accuracy = self.validate()
#     183                 print("Epoch: {} has val accuracy {}".format(epoch, val_accuracy))
#     184                 self.writer.add_scalar('valid/accuracy', val_accuracy, val_iter)
#
# <ipython-input-59-d4dcd5517729> in validate(self)
#      69         # TODO. Should return your validation accuracy
#      70         accuracy = 0.0
# ---> 71         for batch_id, (imgT, quesT, gT) in enumerate(self._val_dataset_loader):
#      72             self._model.eval()  # Set the model to train mode
#      73
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1331             else:
#    1332                 del self._task_info[idx]
# -> 1333                 return self._process_data(data)
#    1334
#    1335     def _try_put_index(self):
#
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1357         self._try_put_index()
#    1358         if isinstance(data, ExceptionWrapper):
# -> 1359             data.reraise()
#    1360         return data
#    1361
#
# /usr/local/lib/python3.8/dist-packages/torch/_utils.py in reraise(self)
#     541             # instantiate since we don't know how to
#     542             raise RuntimeError(msg) from None
# --> 543         raise exception
#     544
#     545
#
# ConnectionAbortedError: Caught ConnectionAbortedError in DataLoader worker process 4.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/worker.py", line 302, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py", line 58, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/_utils/fetch.py", line 58, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "<ipython-input-56-ebbb46f459e8>", line 110, in __getitem__
#     img = default_loader(self.image_dir + '/' + img_name)
#   File "<ipython-input-54-6b57c1e8fc4d>", line 14, in default_loader
#     return pil_loader(path)
#   File "<ipython-input-54-6b57c1e8fc4d>", line 5, in pil_loader
#     img = img.convert('RGB')
# ConnectionAbortedError: [Errno 103] Software caused connection abort

# %%
while True:pass
